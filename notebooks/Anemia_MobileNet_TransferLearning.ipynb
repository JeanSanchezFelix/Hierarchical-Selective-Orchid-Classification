# %%
# Import necessary libraries for file handling, data manipulation, and visualization
import os 
import random
import numpy as np 
import pandas as pd  
import seaborn as sns
import matplotlib.pyplot as plt

# Import libraries for working with images and transformations
from PIL import Image
import cv2 as cv

# Import PyTorch modules for model building, data handling, and evaluation
import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader
from torchinfo import summary

# Import libraries for machine learning metrics and model evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, confusion_matrix, roc_curve
import torchmetrics
from tqdm import tqdm

# %%
data_dir = "C:\\Users\\sebastian.cruz6\\Workspace\\Research\\CAWT-URFI\\cp-anemia-detection\\data\\cp-anemia\\"
anemic_dir = data_dir+"Anemic\\"
non_anemic_dir = data_dir+"Non-anemic\\"

data_sheet_path = data_dir+"Anemia_Data_Collection_Sheet.csv"
data_sheet = pd.read_csv(data_sheet_path)
display(data_sheet)
# Out:
#       IMAGE_ID  HB_LEVEL    Severity  Age(Months)  GENDER      REMARK  \
# 0    Image_001      9.80    Moderate            6  Female      Anemic
# 1    Image_002      9.90    Moderate           24    Male      Anemic
# 2    Image_003     11.10  Non-Anemic           24  Female  Non-anemic
# 3    Image_004     12.50  Non-Anemic           12    Male  Non-anemic
# 4    Image_005      9.90    Moderate           24    Male      Anemic
# ..         ...       ...         ...          ...     ...         ...
# 705  Image_706     12.80  Non-Anemic           48    Male  Non-anemic
# 706  Image_707     11.47  Non-Anemic           48  Female  Non-anemic
# 707  Image_708     11.60  Non-Anemic           60    Male  Non-anemic
# 708  Image_709     12.10  Non-Anemic           48    Male  Non-anemic
# 709  Image_710     11.70  Non-Anemic           24    Male  Non-anemic
#
#                              HOSPITAL     CITY/TOWN    MUNICIPALITY/DISTRICT  \
# 0    Nkawie-Toase Government Hospital  Nkawie-Toase   Atwima Nwabiagya South
# 1           Ejusu Government Hospital         Ejusu       Ejusu Municipality
# 2           Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 3           Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 4          Sunyani Municipal Hospital       Sunyani     Sunyani Municipality
# ..                                ...           ...                      ...
# 705      Bolgatanga Regional Hospital    Bolgatanga  Bolgatanga Municipality
# 706         Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 707   Komfo Anokye Teaching Hospital        Kumasi       Kumasi Metropolitan
# 708      Bolgatanga Regional Hospital    Bolgatanga  Bolgatanga Municipality
# 709         Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
#
#          REGION COUNTRY
# 0       Ashanti   Ghana
# 1       Ashanti   Ghana
# 2     Bono-East   Ghana
# 3     Bono-East   Ghana
# 4          Bono   Ghana
# ..          ...     ...
# 705  Upper East   Ghana
# 706   Bono-East   Ghana
# 707     Ashanti   Ghana
# 708  Upper East   Ghana
# 709   Bono-East   Ghana
#
# [710 rows x 11 columns]

# %%
# Mapping diagnosis to severity
severity_mapping = {
    "Non-Anemic": [1,0,0,0],
    "Mild": [0,1,0,0],
    "Moderate": [0,0,1,0],
    "Severe": [0,0,0,1],
}

data_sheet['SEVERITY_ONEHOT'] = data_sheet['Severity'].map(severity_mapping)
display(data_sheet)
# Out:
#       IMAGE_ID  HB_LEVEL    Severity  Age(Months)  GENDER      REMARK  \
# 0    Image_001      9.80    Moderate            6  Female      Anemic
# 1    Image_002      9.90    Moderate           24    Male      Anemic
# 2    Image_003     11.10  Non-Anemic           24  Female  Non-anemic
# 3    Image_004     12.50  Non-Anemic           12    Male  Non-anemic
# 4    Image_005      9.90    Moderate           24    Male      Anemic
# ..         ...       ...         ...          ...     ...         ...
# 705  Image_706     12.80  Non-Anemic           48    Male  Non-anemic
# 706  Image_707     11.47  Non-Anemic           48  Female  Non-anemic
# 707  Image_708     11.60  Non-Anemic           60    Male  Non-anemic
# 708  Image_709     12.10  Non-Anemic           48    Male  Non-anemic
# 709  Image_710     11.70  Non-Anemic           24    Male  Non-anemic
#
#                              HOSPITAL     CITY/TOWN    MUNICIPALITY/DISTRICT  \
# 0    Nkawie-Toase Government Hospital  Nkawie-Toase   Atwima Nwabiagya South
# 1           Ejusu Government Hospital         Ejusu       Ejusu Municipality
# 2           Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 3           Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 4          Sunyani Municipal Hospital       Sunyani     Sunyani Municipality
# ..                                ...           ...                      ...
# 705      Bolgatanga Regional Hospital    Bolgatanga  Bolgatanga Municipality
# 706         Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 707   Komfo Anokye Teaching Hospital        Kumasi       Kumasi Metropolitan
# 708      Bolgatanga Regional Hospital    Bolgatanga  Bolgatanga Municipality
# 709         Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
#
#          REGION COUNTRY SEVERITY_ONEHOT
# 0       Ashanti   Ghana    [0, 0, 1, 0]
# 1       Ashanti   Ghana    [0, 0, 1, 0]
# 2     Bono-East   Ghana    [1, 0, 0, 0]
# 3     Bono-East   Ghana    [1, 0, 0, 0]
# 4          Bono   Ghana    [0, 0, 1, 0]
# ..          ...     ...             ...
# 705  Upper East   Ghana    [1, 0, 0, 0]
# 706   Bono-East   Ghana    [1, 0, 0, 0]
# 707     Ashanti   Ghana    [1, 0, 0, 0]
# 708  Upper East   Ghana    [1, 0, 0, 0]
# 709   Bono-East   Ghana    [1, 0, 0, 0]
#
# [710 rows x 12 columns]

# %%
# Mapping diagnosis to severity
remark_mapping = {
    "Non-anemic": 0,
    "Anemic": 1
}

data_sheet['REMARK_ONEHOT'] = data_sheet['REMARK'].map(remark_mapping)
display(data_sheet)
# Out:
#       IMAGE_ID  HB_LEVEL    Severity  Age(Months)  GENDER      REMARK  \
# 0    Image_001      9.80    Moderate            6  Female      Anemic
# 1    Image_002      9.90    Moderate           24    Male      Anemic
# 2    Image_003     11.10  Non-Anemic           24  Female  Non-anemic
# 3    Image_004     12.50  Non-Anemic           12    Male  Non-anemic
# 4    Image_005      9.90    Moderate           24    Male      Anemic
# ..         ...       ...         ...          ...     ...         ...
# 705  Image_706     12.80  Non-Anemic           48    Male  Non-anemic
# 706  Image_707     11.47  Non-Anemic           48  Female  Non-anemic
# 707  Image_708     11.60  Non-Anemic           60    Male  Non-anemic
# 708  Image_709     12.10  Non-Anemic           48    Male  Non-anemic
# 709  Image_710     11.70  Non-Anemic           24    Male  Non-anemic
#
#                              HOSPITAL     CITY/TOWN    MUNICIPALITY/DISTRICT  \
# 0    Nkawie-Toase Government Hospital  Nkawie-Toase   Atwima Nwabiagya South
# 1           Ejusu Government Hospital         Ejusu       Ejusu Municipality
# 2           Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 3           Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 4          Sunyani Municipal Hospital       Sunyani     Sunyani Municipality
# ..                                ...           ...                      ...
# 705      Bolgatanga Regional Hospital    Bolgatanga  Bolgatanga Municipality
# 706         Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
# 707   Komfo Anokye Teaching Hospital        Kumasi       Kumasi Metropolitan
# 708      Bolgatanga Regional Hospital    Bolgatanga  Bolgatanga Municipality
# 709         Ahmadiyya Muslim Hospital      Tachiman    Techiman Municipality
#
#          REGION COUNTRY SEVERITY_ONEHOT  REMARK_ONEHOT
# 0       Ashanti   Ghana    [0, 0, 1, 0]              1
# 1       Ashanti   Ghana    [0, 0, 1, 0]              1
# 2     Bono-East   Ghana    [1, 0, 0, 0]              0
# 3     Bono-East   Ghana    [1, 0, 0, 0]              0
# 4          Bono   Ghana    [0, 0, 1, 0]              1
# ..          ...     ...             ...            ...
# 705  Upper East   Ghana    [1, 0, 0, 0]              0
# 706   Bono-East   Ghana    [1, 0, 0, 0]              0
# 707     Ashanti   Ghana    [1, 0, 0, 0]              0
# 708  Upper East   Ghana    [1, 0, 0, 0]              0
# 709   Bono-East   Ghana    [1, 0, 0, 0]              0
#
# [710 rows x 13 columns]

# %%
device = torch.device('cpu')

# Default device
device = torch.device('cpu')

# Check for CUDA availability
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    print("CUDA is not available, using CPU.")

print(f"Selected device: {device}")
# Out:
# CUDA is not available, using CPU.
# Selected device: cpu

# %%
# Define any data augmentations or transformations
transform = transforms.Compose([
    transforms.Resize((256,192)),
    transforms.RandomHorizontalFlip(p=np.random.rand()),
    transforms.RandomVerticalFlip(p=np.random.rand()),
    transforms.RandomRotation(degrees=np.random.randint(0,360)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Create datasets from CSV files (assuming you have a custom dataset class)
class DRImageDataset(Dataset):
    def __init__(self, dir, df, transform=None):
        """
        Initializes the dataset with a directory and DataFrame, and optional transformations.
        
        Parameters:
        dir (str): Path to the directory containing images.
        df (DataFrame): DataFrame containing image IDs and labels.
        transform (callable, optional): Optional transformations to be applied to the images.
        """
        self.dir = dir
        self.df = df
        self.transform = transform

    def __len__(self):
        """
        Returns the total number of samples in the dataset.
        
        Returns:
        int: Number of samples.
        """
        return len(self.df)

    def __getitem__(self, idx):
        """
        Retrieves the image and label at the specified index.
        
        Parameters:
        idx (int): Index of the sample to retrieve.
        
        Returns:
        tuple: (image, target, description) where image is the transformed image, target is the label, and description is the severity description.
        """
        row = self.df.iloc[idx]
        img_id = row['IMAGE_ID']
        img_folder = row['REMARK']
        img_path = os.path.join(self.dir, img_folder, img_id + ".png")
        # print(img_path)
        img = Image.open(img_path).convert('RGB')
        
        if self.transform:
            img = self.transform(img)
        
        label = torch.tensor(row['REMARK_ONEHOT'], dtype=torch.int64)
        # print(img.size())
        # print(img)
        # print(label.size())
        # print(label)
        descriptor = img_folder
        
        return img, label, descriptor

# Create the dataset
image_dataset = DRImageDataset(data_dir, data_sheet, transform=transform)
# image_dataset = DRImageDataset(data_dir, sample_df, transform=transform)

# Split the dataset
train_dataset, test_dataset = train_test_split(image_dataset, test_size=0.3, shuffle=True)
val_dataset, test_dataset = train_test_split(test_dataset, test_size=0.5, shuffle=True)

print(f"Train Dataset: {len(train_dataset)}, Val Dataset:{len(val_dataset)}, Test Dataset: {len(test_dataset)}")

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
# Out:
# Train Dataset: 497, Val Dataset: 106, Test Dataset: 107

# %%
def train(dataloader, model, loss_fn, optimizer, cumulative_metrics):
    """
    Training loop for one epoch.
    
    Parameters:
    dataloader (DataLoader): DataLoader containing the training data.
    model (torch.nn.Module): PyTorch model to be trained.
    loss_fn (callable): Loss function.
    optimizer (torch.optim.Optimizer): Optimizer for updating the model parameters.
    cumulative_metrics (CumulativeMetrics): Instance of CumulativeMetrics for tracking metrics.
    
    Returns:
    tuple: Average loss and average accuracy for the epoch.
    """
    model.train()
    size = len(dataloader.dataset)
    batch_losses = []
    batch_acc = []
    cumulative_metrics.reset()

    for _, (X, y, _) in enumerate(dataloader):
        X, y = X.to(device), y.to(device).unsqueeze(1)
        y = y.to(torch.float32)
        
        optimizer.zero_grad()
        pred = model(X)

        # logits = model(X)
        # probabilities = torch.softmax(logits, dim=1) # Convert logits to probabilities using softmax
        # predicted_classes = torch.argmax(probabilities, dim=1) # Get the predicted class (index of the highest probability)
        # pred = torch.nn.functional.one_hot(predicted_classes, num_classes=5).float() # Convert class indices to one-hot encoding

        loss = loss_fn(pred, y)        
        loss.backward()
        optimizer.step()
        
        batch_losses.append(loss.item())        
        cumulative_metrics.update(pred, y)
    
    avg_loss = sum(batch_losses) / len(batch_losses)    
    performance_metrics = cumulative_metrics.get_cumulative_metrics()

    return avg_loss, performance_metrics

def eval(dataloader, model, loss_fn, mode, cumulative_metrics):
    """
    Testing loop to evaluate the model on the test dataset.
    
    Parameters:
    dataloader (DataLoader): DataLoader containing the test data.
    model (torch.nn.Module): PyTorch model to be evaluated.
    loss_fn (callable): Loss function.
    cumulative_metrics (CumulativeMetrics): Instance of CumulativeMetrics for tracking metrics.
    
    Returns:
    tuple: Average loss and average accuracy for the test dataset.
    """
    model.eval()
    size = len(dataloader.dataset)
    batch_losses = []
    cumulative_metrics.reset()

    if mode == "Testing":
        with torch.no_grad():
            for _, (X, y, _) in enumerate(dataloader):
                X, y = X.to(device), y.to(device).unsqueeze(1)
                y = y.to(torch.float32)

                pred = model(X)
                
                loss = loss_fn(pred, y)

                batch_losses.append(loss.item())
                cumulative_metrics.update(pred, y)
        
        avg_loss = sum(batch_losses) / len(batch_losses)    
        performance_metrics = cumulative_metrics.get_cumulative_metrics()

    
    if mode == "Validation":
        with torch.no_grad():
            for _, (X, y, _) in enumerate(dataloader):
                X, y = X.to(device), y.to(device).unsqueeze(1)
                y = y.to(torch.float32)

                pred = model(X)
                
                loss = loss_fn(pred, y)

                batch_losses.append(loss.item())
                cumulative_metrics.update(pred, y)
        
        avg_loss = sum(batch_losses) / len(batch_losses)    
        performance_metrics = cumulative_metrics.get_cumulative_metrics()
    
    return avg_loss, performance_metrics

# %%
import torch
import torchmetrics
from sklearn.metrics import roc_auc_score

class CumulativeMetrics:
    def __init__(self):
        # Initialize torchmetrics for binary classification
        self.accuracy = torchmetrics.Accuracy(task="binary").to(device)
        self.precision = torchmetrics.Precision(task="binary", average="macro").to(device)
        self.recall = torchmetrics.Recall(task="binary", average="macro").to(device)
        self.f1_score = torchmetrics.F1Score(task="binary", average="macro").to(device)

        # For scikit-learn metrics, we'll store the true and predicted values for each batch
        self.y_true_all = []
        self.y_pred_all = []
        self.y_score_all = []

        self.reset()

    def reset(self):
        # Reset torchmetrics accumulators
        self.cum_acc = 0.0
        self.cum_prec = 0.0
        self.cum_rec = 0.0
        self.cum_f1 = 0.0
        self.num_batches = 0
        
        # Reset true and predicted values lists for sklearn
        self.y_true_all = []
        self.y_pred_all = []
        self.y_score_all = []

    def update(self, y_pred: torch.Tensor, y_true: torch.Tensor):
        # For binary classification, y_true is already a class label (0 or 1)
        y_pred_class = torch.round(torch.sigmoid(y_pred)).int()  # Get predicted class by rounding sigmoid output

        # Append predictions and true labels for scikit-learn metrics later
        self.y_true_all.extend(y_true.cpu().numpy())
        self.y_pred_all.extend(y_pred_class.cpu().numpy())
        self.y_score_all.extend(torch.sigmoid(y_pred).detach().cpu().numpy())  # Probabilities/logits for AUC

        # Update cumulative torchmetrics
        acc = self.accuracy(y_pred_class, y_true).item()
        prec = self.precision(y_pred_class, y_true).item()
        rec = self.recall(y_pred_class, y_true).item()
        f1 = self.f1_score(y_pred_class, y_true).item()

        self.cum_acc += acc
        self.cum_prec += prec
        self.cum_rec += rec
        self.cum_f1 += f1
        self.num_batches += 1

    def get_cumulative_metrics(self):
        avg_acc = self.cum_acc / self.num_batches
        avg_prec = self.cum_prec / self.num_batches
        avg_rec = self.cum_rec / self.num_batches
        avg_f1 = self.cum_f1 / self.num_batches

        # Ensure y_true_all contains basic data types before using set
        y_true_list = [int(val) for val in self.y_true_all]

        # Compute AUC using sklearn
        if len(self.y_score_all) > 0 and len(set(y_true_list)) > 1:
            auc = roc_auc_score(self.y_true_all, self.y_score_all)
        else:
            auc = None  # If no valid score or only one class present

        performance_metrics = {
            "Accuracy": avg_acc,
            "Precision": avg_prec,
            "Recall": avg_rec,
            "F1 Score": avg_f1,
            "AUC": auc,
        }        
        return performance_metrics

# %%
# Load MobileNetV2 with pretrained weights disabled
# mbnetv2 = models.mobilenet_v2(weights="IMAGENET1K_V2")
mbnetv2 = models.mobilenet_v2(weights=None)

# Modify the classifier to output 5 classes (corresponding to the severity levels)
mbnetv2.classifier[1] = torch.nn.Linear(in_features=1280, out_features=1)
mbnetv2 = mbnetv2.to(device)

# Print the model summary
print(summary(mbnetv2))
# Out:
# ===========================================================================
# Layer (type:depth-idx)                             Param #
# ===========================================================================
# MobileNetV2                                        --
# ├─Sequential: 1-1                                  --
# │    └─Conv2dNormActivation: 2-1                   --
# │    │    └─Conv2d: 3-1                            864
# │    │    └─BatchNorm2d: 3-2                       64
# │    │    └─ReLU6: 3-3                             --
# │    └─InvertedResidual: 2-2                       --
# │    │    └─Sequential: 3-4                        896
# │    └─InvertedResidual: 2-3                       --
# │    │    └─Sequential: 3-5                        5,136
# │    └─InvertedResidual: 2-4                       --
# │    │    └─Sequential: 3-6                        8,832
# │    └─InvertedResidual: 2-5                       --
# │    │    └─Sequential: 3-7                        10,000
# │    └─InvertedResidual: 2-6                       --
# │    │    └─Sequential: 3-8                        14,848
# │    └─InvertedResidual: 2-7                       --
# │    │    └─Sequential: 3-9                        14,848
# │    └─InvertedResidual: 2-8                       --
# │    │    └─Sequential: 3-10                       21,056
# │    └─InvertedResidual: 2-9                       --
# │    │    └─Sequential: 3-11                       54,272
# │    └─InvertedResidual: 2-10                      --
# │    │    └─Sequential: 3-12                       54,272
# │    └─InvertedResidual: 2-11                      --
# │    │    └─Sequential: 3-13                       54,272
# │    └─InvertedResidual: 2-12                      --
# │    │    └─Sequential: 3-14                       66,624
# │    └─InvertedResidual: 2-13                      --
# │    │    └─Sequential: 3-15                       118,272
# │    └─InvertedResidual: 2-14                      --
# │    │    └─Sequential: 3-16                       118,272
# │    └─InvertedResidual: 2-15                      --
# │    │    └─Sequential: 3-17                       155,264
# │    └─InvertedResidual: 2-16                      --
# │    │    └─Sequential: 3-18                       320,000
# │    └─InvertedResidual: 2-17                      --
# │    │    └─Sequential: 3-19                       320,000
# │    └─InvertedResidual: 2-18                      --
# │    │    └─Sequential: 3-20                       473,920
# │    └─Conv2dNormActivation: 2-19                  --
# │    │    └─Conv2d: 3-21                           409,600
# │    │    └─BatchNorm2d: 3-22                      2,560
# │    │    └─ReLU6: 3-23                            --
# ├─Sequential: 1-2                                  --
# │    └─Dropout: 2-20                               --
# │    └─Linear: 2-21                                1,281
# ===========================================================================
# Total params: 2,225,153
# Trainable params: 2,225,153
# Non-trainable params: 0
# ===========================================================================

# %%
import torch
from torch.utils.data import Subset
from sklearn.model_selection import KFold
from tqdm import tqdm

# Assuming `CumulativeMetrics` is already implemented elsewhere
cumulative_metrics = CumulativeMetrics()  # Instance to track metrics (accuracy, precision, etc.)

# Define any data augmentations or transformations
transform = transforms.Compose([
    transforms.Resize((256,192)),
    transforms.RandomHorizontalFlip(p=np.random.rand()),
    transforms.RandomVerticalFlip(p=np.random.rand()),
    transforms.RandomRotation(degrees=np.random.randint(0,360)),
    transforms.RandomAffine(degrees=np.random.randint(0,360)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Custom dataset class
class DRImageDataset(Dataset):
    def __init__(self, dir, df, transform=None):
        self.dir = dir
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img_id = row['IMAGE_ID']
        img_folder = row['REMARK']
        img_path = os.path.join(self.dir, img_folder, img_id + ".png")
        img = Image.open(img_path).convert('RGB')
        
        if self.transform:
            img = self.transform(img)
        
        label = torch.tensor(row['REMARK_ONEHOT'], dtype=torch.int64)
        descriptor = img_folder
        
        return img, label, descriptor

# Load the dataset
image_dataset = DRImageDataset(data_dir, data_sheet, transform=transform)

train_dataset, test_dataset = train_test_split(image_dataset, test_size=0.15, shuffle=True)

# Iterate over each fold
EPOCHS = 150
FOLDS = 5

# 5-fold cross-validation setup
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=42)

# Initialize model, loss function, and optimizer
model = mbnetv2  # Your model instance
loss_fn = torch.nn.BCEWithLogitsLoss()  # Binary cross-entropy loss (modify according to your task)
optimizer = torch.optim.Adam(model.parameters(), lr=10e-4)  # Adam optimizer (example)

# Path where the model with the best precision is saved
weights_path = "C:\\Users\\sebastian.cruz6\\Workspace\\Research\\CAWT-URFI\\cp-anemia-detection\\notebooks\\weights"

best_val_f1score = -float('inf')  # Initialize with a very low value

train_metrics_df = []
val_metrics_df = []

for epochs in range(EPOCHS):
    print(f"\nEpoch {epochs+1}/{EPOCHS}")
    fold = 1
    fold_best_train_f1score = -float('inf')

    for train_idx, val_idx in kf.split(train_dataset):
        # Create subset datasets for training and validation
        train_subset = Subset(image_dataset, train_idx)
        val_subset = Subset(image_dataset, val_idx)

        # Create data loaders
        train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
        val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)

        if fold == FOLDS:
            # Validation loop
            avg_val_loss, val_metrics = eval(val_loader, model, loss_fn, mode="Validation", cumulative_metrics=cumulative_metrics)
            avg_val_accuracy, avg_val_precision, avg_val_recall, avg_val_f1, avg_val_auc = val_metrics.values()

            print(f"\nValidation: \tFold {fold} - Loss: {avg_val_loss:.4f}, Accuracy: {avg_val_accuracy:.4f}, Precision: {avg_val_precision:.4f}, Recall: {avg_val_recall:.4f}, F1 Score: {avg_val_f1:.4f}, AUC Score: {avg_val_auc:.4f}")

            # Save the best model based on validation precision
            if avg_val_f1 > best_val_f1score:
                best_val_f1score = avg_val_f1
                
                val_metrics_dict = {**{"Loss":avg_val_loss}, **val_metrics}
                val_metrics_df.append(val_metrics_dict)

                torch.save(mbnetv2.state_dict(), f'{weights_path}\\mbnetv2_best_f1score.pth')
                print(f"Model with best precision during Validation saved at epoch {epochs + 1} with F1 Score of {best_val_f1score:.4f}")
        # """
        # Implement early stopping here as an elif statement
        # """
        else:
            # Training loop
            avg_train_loss, train_metrics = train(train_loader, model, loss_fn, optimizer, cumulative_metrics)
            avg_train_accuracy, avg_train_precision, avg_train_recall, avg_train_f1, avg_train_auc = train_metrics.values()

            if avg_train_f1 > fold_best_train_f1score:
                fold_best_train_f1score = avg_train_f1

                print(f"Training: \tFold {fold} - Loss: {avg_train_loss:.4f}, Accuracy: {avg_train_accuracy:.4f}, Precision: {avg_train_precision:.4f}, Recall: {avg_train_recall:.4f}, F1 Score: {avg_train_f1:.4f}, AUC Score: {avg_train_auc:.4f}")
                train_metrics_dict = {**{"Loss":avg_train_loss}, **train_metrics}
                train_metrics_df.append(train_metrics_dict)

        # Reset metrics and model (if needed) for next fold
        cumulative_metrics.reset()

        fold += 1
# Out:
# Epoch 1/150
# Training: 	Fold 1 - Loss: 0.6829, Accuracy: 0.6055, Precision: 0.6522, Recall: 0.8098, F1 Score: 0.6981, AUC Score: 0.5289
# Training: 	Fold 3 - Loss: 0.7099, Accuracy: 0.6016, Precision: 0.6301, Recall: 0.8265, F1 Score: 0.7036, AUC Score: 0.4910
# Training: 	Fold 4 - Loss: 0.6723, Accuracy: 0.5885, Precision: 0.6084, Recall: 0.8967, F1 Score: 0.7201, AUC Score: 0.5194
#
# Validation: 	Fold 5 - Loss: 0.6972, Accuracy: 0.5807, Precision: 0.5807, Recall: 1.0000, F1 Score: 0.7163, AUC Score: 0.6223
# Model with best precision during Validation saved at epoch 1 with F1 Score of 0.7163
#
# Epoch 2/150
# Training: 	Fold 1 - Loss: 0.6879, Accuracy: 0.5352, Precision: 0.5640, Recall: 0.7900, F1 Score: 0.6530, AUC Score: 0.5464
# Training: 	Fold 2 - Loss: 0.6643, Accuracy: 0.6074, Precision: 0.6112, Recall: 0.9462, F1 Score: 0.7378, AUC Score: 0.5677
#
# Validation: 	Fold 5 - Loss: 0.7095, Accuracy: 0.5807, Precision: 0.5807, Recall: 1.0000, F1 Score: 0.7163, AUC Score: 0.5027
#
# Epoch 3/150
# Training: 	Fold 1 - Loss: 0.6936, Accuracy: 0.5566, Precision: 0.5843, Recall: 0.8481, F1 Score: 0.6834, AUC Score: 0.4969
# Training: 	Fold 2 - Loss: 0.6869, Accuracy: 0.6055, Precision: 0.6184, Recall: 0.9145, F1 Score: 0.7324, AUC Score: 0.5453
#
# Validation: 	Fold 5 - Loss: 0.6591, Accuracy: 0.6250, Precision: 0.6149, Recall: 0.9844, F1 Score: 0.7351, AUC Score: 0.6056
# Model with best precision during Validation saved at epoch 3 with F1 Score of 0.7351
#
# Epoch 4/150
# Training: 	Fold 1 - Loss: 0.6800, Accuracy: 0.6016, Precision: 0.5749, Recall: 0.8613, F1 Score: 0.6783, AUC Score: 0.5729
# Training: 	Fold 3 - Loss: 0.6621, Accuracy: 0.6387, Precision: 0.6522, Recall: 0.8672, F1 Score: 0.7347, AUC Score: 0.5722
# Training: 	Fold 4 - Loss: 0.6685, Accuracy: 0.6237, Precision: 0.6432, Recall: 0.9227, F1 Score: 0.7469, AUC Score: 0.5857
#
# Validation: 	Fold 5 - Loss: 0.7019, Accuracy: 0.5781, Precision: 0.6330, Recall: 0.7102, F1 Score: 0.6351, AUC Score: 0.5882
#
# Epoch 5/150
# Training: 	Fold 1 - Loss: 0.6603, Accuracy: 0.6074, Precision: 0.6093, Recall: 0.9391, F1 Score: 0.7348, AUC Score: 0.6140
# Training: 	Fold 2 - Loss: 0.6394, Accuracy: 0.6426, Precision: 0.6760, Recall: 0.8817, F1 Score: 0.7505, AUC Score: 0.6381
# Training: 	Fold 4 - Loss: 0.6165, Accuracy: 0.6855, Precision: 0.6805, Recall: 0.9204, F1 Score: 0.7774, AUC Score: 0.6792
#
# Validation: 	Fold 5 - Loss: 0.6959, Accuracy: 0.6641, Precision: 0.6597, Recall: 0.8775, F1 Score: 0.7320, AUC Score: 0.6871
#
# Epoch 6/150
# Training: 	Fold 1 - Loss: 0.6711, Accuracy: 0.6504, Precision: 0.6559, Recall: 0.8774, F1 Score: 0.7465, AUC Score: 0.6343
# Training: 	Fold 2 - Loss: 0.6458, Accuracy: 0.6582, Precision: 0.6742, Recall: 0.8779, F1 Score: 0.7566, AUC Score: 0.6056
#
# Validation: 	Fold 5 - Loss: 0.6513, Accuracy: 0.6302, Precision: 0.6414, Recall: 0.8590, F1 Score: 0.7109, AUC Score: 0.6789
#
# Epoch 7/150
# Training: 	Fold 1 - Loss: 0.6370, Accuracy: 0.6602, Precision: 0.6702, Recall: 0.8585, F1 Score: 0.7464, AUC Score: 0.6773
# Training: 	Fold 4 - Loss: 0.6709, Accuracy: 0.6204, Precision: 0.6203, Recall: 0.9560, F1 Score: 0.7469, AUC Score: 0.6392
#
# Validation: 	Fold 5 - Loss: 0.6687, Accuracy: 0.6380, Precision: 0.6440, Recall: 0.7862, F1 Score: 0.6901, AUC Score: 0.7130
#
# Epoch 8/150
# Training: 	Fold 1 - Loss: 0.6770, Accuracy: 0.5957, Precision: 0.6044, Recall: 0.8281, F1 Score: 0.6932, AUC Score: 0.6190
# Training: 	Fold 2 - Loss: 0.6132, Accuracy: 0.7012, Precision: 0.7197, Recall: 0.8426, F1 Score: 0.7718, AUC Score: 0.6881
#
# Validation: 	Fold 5 - Loss: 0.8894, Accuracy: 0.5339, Precision: 0.6667, Recall: 0.3479, F1 Score: 0.4500, AUC Score: 0.6380
#
# Epoch 9/150
# Training: 	Fold 1 - Loss: 0.6709, Accuracy: 0.6523, Precision: 0.6653, Recall: 0.8583, F1 Score: 0.7433, AUC Score: 0.6119
# Training: 	Fold 2 - Loss: 0.6218, Accuracy: 0.6445, Precision: 0.6662, Recall: 0.9489, F1 Score: 0.7642, AUC Score: 0.7019
# Training: 	Fold 4 - Loss: 0.5820, Accuracy: 0.6934, Precision: 0.6942, Recall: 0.8877, F1 Score: 0.7751, AUC Score: 0.7281
#
# Validation: 	Fold 5 - Loss: 0.6360, Accuracy: 0.6979, Precision: 0.6769, Recall: 0.8942, F1 Score: 0.7531, AUC Score: 0.6996
# Model with best precision during Validation saved at epoch 9 with F1 Score of 0.7531
#
# Epoch 10/150
# Training: 	Fold 1 - Loss: 0.5901, Accuracy: 0.7070, Precision: 0.7129, Recall: 0.8657, F1 Score: 0.7733, AUC Score: 0.7277
#
# Validation: 	Fold 5 - Loss: 0.6153, Accuracy: 0.6693, Precision: 0.6769, Recall: 0.7616, F1 Score: 0.7033, AUC Score: 0.7388
#
# Epoch 11/150
# Training: 	Fold 1 - Loss: 0.6275, Accuracy: 0.6855, Precision: 0.7042, Recall: 0.8275, F1 Score: 0.7563, AUC Score: 0.6708
# Training: 	Fold 3 - Loss: 0.6191, Accuracy: 0.6855, Precision: 0.6616, Recall: 0.9538, F1 Score: 0.7761, AUC Score: 0.6979
#
# Validation: 	Fold 5 - Loss: 0.7783, Accuracy: 0.4453, Precision: 0.7500, Recall: 0.0416, F1 Score: 0.0785, AUC Score: 0.6411
#
# Epoch 12/150
# Training: 	Fold 1 - Loss: 0.6097, Accuracy: 0.6855, Precision: 0.6842, Recall: 0.8792, F1 Score: 0.7665, AUC Score: 0.6936
# Training: 	Fold 2 - Loss: 0.5968, Accuracy: 0.7031, Precision: 0.6991, Recall: 0.9220, F1 Score: 0.7881, AUC Score: 0.7172
#
# Validation: 	Fold 5 - Loss: 0.5734, Accuracy: 0.6354, Precision: 0.6661, Recall: 0.7865, F1 Score: 0.6982, AUC Score: 0.7491
#
# Epoch 13/150
# Training: 	Fold 1 - Loss: 0.5729, Accuracy: 0.6914, Precision: 0.6987, Recall: 0.8658, F1 Score: 0.7650, AUC Score: 0.7679
#
# Validation: 	Fold 5 - Loss: 0.6560, Accuracy: 0.6406, Precision: 0.6574, Recall: 0.7709, F1 Score: 0.6951, AUC Score: 0.6874
#
# Epoch 14/150
# Training: 	Fold 1 - Loss: 0.6035, Accuracy: 0.6719, Precision: 0.6770, Recall: 0.8749, F1 Score: 0.7592, AUC Score: 0.6907
# Training: 	Fold 2 - Loss: 0.5956, Accuracy: 0.6973, Precision: 0.6882, Recall: 0.9300, F1 Score: 0.7834, AUC Score: 0.7094
#
# Validation: 	Fold 5 - Loss: 0.5603, Accuracy: 0.6771, Precision: 0.6803, Recall: 0.8174, F1 Score: 0.7260, AUC Score: 0.7505
#
# Epoch 15/150
# Training: 	Fold 1 - Loss: 0.5579, Accuracy: 0.7031, Precision: 0.7139, Recall: 0.8517, F1 Score: 0.7708, AUC Score: 0.7502
# Training: 	Fold 2 - Loss: 0.5602, Accuracy: 0.7246, Precision: 0.7217, Recall: 0.8950, F1 Score: 0.7945, AUC Score: 0.7649
#
# Validation: 	Fold 5 - Loss: 0.5084, Accuracy: 0.7344, Precision: 0.7167, Recall: 0.8746, F1 Score: 0.7709, AUC Score: 0.8002
# Model with best precision during Validation saved at epoch 15 with F1 Score of 0.7709
#
# Epoch 16/150
# Training: 	Fold 1 - Loss: 0.5265, Accuracy: 0.7090, Precision: 0.7099, Recall: 0.8862, F1 Score: 0.7793, AUC Score: 0.7942
#
# Validation: 	Fold 5 - Loss: 0.6212, Accuracy: 0.6536, Precision: 0.6555, Recall: 0.8320, F1 Score: 0.7145, AUC Score: 0.7235
#
# Epoch 17/150
# Training: 	Fold 1 - Loss: 0.6029, Accuracy: 0.6602, Precision: 0.7000, Recall: 0.7702, F1 Score: 0.7235, AUC Score: 0.7267
# Training: 	Fold 2 - Loss: 0.5998, Accuracy: 0.6816, Precision: 0.7056, Recall: 0.8183, F1 Score: 0.7538, AUC Score: 0.7045
# Training: 	Fold 4 - Loss: 0.5683, Accuracy: 0.7005, Precision: 0.7286, Recall: 0.8148, F1 Score: 0.7642, AUC Score: 0.7708
#
# Validation: 	Fold 5 - Loss: 0.5115, Accuracy: 0.7318, Precision: 0.7149, Recall: 0.8540, F1 Score: 0.7668, AUC Score: 0.8056
#
# Epoch 18/150
# Training: 	Fold 1 - Loss: 0.5587, Accuracy: 0.6973, Precision: 0.7156, Recall: 0.8317, F1 Score: 0.7645, AUC Score: 0.7569
# Training: 	Fold 2 - Loss: 0.5367, Accuracy: 0.7129, Precision: 0.7470, Recall: 0.8557, F1 Score: 0.7846, AUC Score: 0.7896
#
# Validation: 	Fold 5 - Loss: 0.8353, Accuracy: 0.4740, Precision: 0.7500, Recall: 0.0881, F1 Score: 0.1551, AUC Score: 0.7701
#
# Epoch 19/150
# Training: 	Fold 1 - Loss: 0.5212, Accuracy: 0.7500, Precision: 0.7457, Recall: 0.8915, F1 Score: 0.8072, AUC Score: 0.7857
#
# Validation: 	Fold 5 - Loss: 0.7225, Accuracy: 0.7266, Precision: 0.7383, Recall: 0.7606, F1 Score: 0.7379, AUC Score: 0.7761
#
# Epoch 20/150
# Training: 	Fold 1 - Loss: 0.6962, Accuracy: 0.6035, Precision: 0.6331, Recall: 0.8070, F1 Score: 0.7025, AUC Score: 0.6296
# Training: 	Fold 2 - Loss: 0.6345, Accuracy: 0.6250, Precision: 0.6406, Recall: 0.8993, F1 Score: 0.7404, AUC Score: 0.6484
# Training: 	Fold 3 - Loss: 0.6248, Accuracy: 0.6328, Precision: 0.6326, Recall: 0.9580, F1 Score: 0.7559, AUC Score: 0.6624
#
# Validation: 	Fold 5 - Loss: 0.5896, Accuracy: 0.6406, Precision: 0.6314, Recall: 0.9105, F1 Score: 0.7256, AUC Score: 0.7280
#
# Epoch 21/150
# Training: 	Fold 1 - Loss: 0.6104, Accuracy: 0.6172, Precision: 0.6295, Recall: 0.7855, F1 Score: 0.6956, AUC Score: 0.7295
# Training: 	Fold 3 - Loss: 0.5927, Accuracy: 0.6895, Precision: 0.7039, Recall: 0.8334, F1 Score: 0.7599, AUC Score: 0.7153
#
# Validation: 	Fold 5 - Loss: 0.5922, Accuracy: 0.6536, Precision: 0.6339, Recall: 0.9084, F1 Score: 0.7287, AUC Score: 0.7795
#
# Epoch 22/150
# Training: 	Fold 1 - Loss: 0.5765, Accuracy: 0.6914, Precision: 0.7361, Recall: 0.8098, F1 Score: 0.7583, AUC Score: 0.7625
# Training: 	Fold 4 - Loss: 0.5557, Accuracy: 0.7467, Precision: 0.7639, Recall: 0.8273, F1 Score: 0.7883, AUC Score: 0.8003
#
# Validation: 	Fold 5 - Loss: 0.6377, Accuracy: 0.6615, Precision: 0.6493, Recall: 0.7947, F1 Score: 0.7058, AUC Score: 0.7710
#
# Epoch 23/150
# Training: 	Fold 1 - Loss: 0.5856, Accuracy: 0.6855, Precision: 0.6791, Recall: 0.7460, F1 Score: 0.7056, AUC Score: 0.7651
# Training: 	Fold 2 - Loss: 0.5440, Accuracy: 0.6855, Precision: 0.7158, Recall: 0.7544, F1 Score: 0.7319, AUC Score: 0.7933
# Training: 	Fold 3 - Loss: 0.5437, Accuracy: 0.7461, Precision: 0.7445, Recall: 0.8734, F1 Score: 0.8005, AUC Score: 0.7659
# Training: 	Fold 4 - Loss: 0.5049, Accuracy: 0.7389, Precision: 0.7473, Recall: 0.8840, F1 Score: 0.8032, AUC Score: 0.8154
#
# Validation: 	Fold 5 - Loss: 0.9946, Accuracy: 0.4427, Precision: 0.5000, Recall: 0.0444, F1 Score: 0.0813, AUC Score: 0.6138
#
# Epoch 24/150
# Training: 	Fold 1 - Loss: 0.5798, Accuracy: 0.6680, Precision: 0.6761, Recall: 0.7995, F1 Score: 0.7254, AUC Score: 0.7892
# Training: 	Fold 2 - Loss: 0.5817, Accuracy: 0.6973, Precision: 0.7874, Recall: 0.7304, F1 Score: 0.7489, AUC Score: 0.7682
# Training: 	Fold 3 - Loss: 0.5258, Accuracy: 0.7188, Precision: 0.7225, Recall: 0.8906, F1 Score: 0.7882, AUC Score: 0.8000
# Training: 	Fold 4 - Loss: 0.5373, Accuracy: 0.7565, Precision: 0.7377, Recall: 0.9040, F1 Score: 0.8062, AUC Score: 0.8302
#
# Validation: 	Fold 5 - Loss: 0.6137, Accuracy: 0.6510, Precision: 0.7833, Recall: 0.4453, F1 Score: 0.5610, AUC Score: 0.7840
#
# Epoch 25/150
# Training: 	Fold 1 - Loss: 0.5349, Accuracy: 0.7285, Precision: 0.7571, Recall: 0.8155, F1 Score: 0.7776, AUC Score: 0.8024
# Training: 	Fold 2 - Loss: 0.5126, Accuracy: 0.7598, Precision: 0.7610, Recall: 0.8924, F1 Score: 0.8184, AUC Score: 0.7918
#
# Validation: 	Fold 5 - Loss: 0.4573, Accuracy: 0.7604, Precision: 0.7888, Recall: 0.6959, F1 Score: 0.7322, AUC Score: 0.8690
#
# Epoch 26/150
# Training: 	Fold 1 - Loss: 0.5359, Accuracy: 0.7266, Precision: 0.7564, Recall: 0.8257, F1 Score: 0.7793, AUC Score: 0.8045
#
# Validation: 	Fold 5 - Loss: 0.5685, Accuracy: 0.6771, Precision: 0.7617, Recall: 0.6220, F1 Score: 0.6727, AUC Score: 0.7542
#
# Epoch 27/150
# Training: 	Fold 1 - Loss: 0.5525, Accuracy: 0.7148, Precision: 0.7532, Recall: 0.7841, F1 Score: 0.7617, AUC Score: 0.7548
# Training: 	Fold 2 - Loss: 0.5374, Accuracy: 0.7539, Precision: 0.7629, Recall: 0.8621, F1 Score: 0.8039, AUC Score: 0.7815
#
# Validation: 	Fold 5 - Loss: 0.8983, Accuracy: 0.4896, Precision: 0.7500, Recall: 0.1006, F1 Score: 0.1747, AUC Score: 0.7712
#
# Epoch 28/150
# Training: 	Fold 1 - Loss: 0.5369, Accuracy: 0.7070, Precision: 0.7450, Recall: 0.7930, F1 Score: 0.7601, AUC Score: 0.7963
# Training: 	Fold 3 - Loss: 0.5515, Accuracy: 0.7227, Precision: 0.7256, Recall: 0.8658, F1 Score: 0.7854, AUC Score: 0.7652
# Training: 	Fold 4 - Loss: 0.5108, Accuracy: 0.7578, Precision: 0.7622, Recall: 0.8618, F1 Score: 0.8069, AUC Score: 0.8075
#
# Validation: 	Fold 5 - Loss: 0.4912, Accuracy: 0.7240, Precision: 0.7100, Recall: 0.8746, F1 Score: 0.7654, AUC Score: 0.8394
#
# Epoch 29/150
# Training: 	Fold 1 - Loss: 0.5488, Accuracy: 0.7031, Precision: 0.7150, Recall: 0.7993, F1 Score: 0.7511, AUC Score: 0.8144
# Training: 	Fold 2 - Loss: 0.5014, Accuracy: 0.7734, Precision: 0.8066, Recall: 0.8301, F1 Score: 0.8109, AUC Score: 0.8290
#
# Validation: 	Fold 5 - Loss: 1.0583, Accuracy: 0.6484, Precision: 0.6209, Recall: 0.9677, F1 Score: 0.7409, AUC Score: 0.8053
#
# Epoch 30/150
# Training: 	Fold 1 - Loss: 0.5974, Accuracy: 0.7148, Precision: 0.7410, Recall: 0.8071, F1 Score: 0.7674, AUC Score: 0.7446
# Training: 	Fold 2 - Loss: 0.5408, Accuracy: 0.7129, Precision: 0.7108, Recall: 0.8910, F1 Score: 0.7855, AUC Score: 0.7879
#
# Validation: 	Fold 5 - Loss: 0.4766, Accuracy: 0.7708, Precision: 0.7286, Recall: 0.9339, F1 Score: 0.8060, AUC Score: 0.8579
# Model with best precision during Validation saved at epoch 30 with F1 Score of 0.8060
#
# Epoch 31/150
# Training: 	Fold 1 - Loss: 0.5337, Accuracy: 0.7441, Precision: 0.7633, Recall: 0.8182, F1 Score: 0.7868, AUC Score: 0.8048
# Training: 	Fold 2 - Loss: 0.4863, Accuracy: 0.7695, Precision: 0.7989, Recall: 0.8712, F1 Score: 0.8246, AUC Score: 0.8502
#
# Validation: 	Fold 5 - Loss: 0.6394, Accuracy: 0.6953, Precision: 0.6752, Recall: 0.9275, F1 Score: 0.7598, AUC Score: 0.7670
#
# Epoch 32/150
# Training: 	Fold 1 - Loss: 0.5551, Accuracy: 0.6758, Precision: 0.7399, Recall: 0.7582, F1 Score: 0.7376, AUC Score: 0.7743
# Training: 	Fold 2 - Loss: 0.5197, Accuracy: 0.7344, Precision: 0.7393, Recall: 0.8876, F1 Score: 0.8008, AUC Score: 0.8020
#
# Validation: 	Fold 5 - Loss: 0.6739, Accuracy: 0.5859, Precision: 0.7472, Recall: 0.4386, F1 Score: 0.5407, AUC Score: 0.6999
#
# Epoch 33/150
# Training: 	Fold 1 - Loss: 0.5917, Accuracy: 0.7090, Precision: 0.7007, Recall: 0.8967, F1 Score: 0.7813, AUC Score: 0.7000
# Training: 	Fold 2 - Loss: 0.5388, Accuracy: 0.7480, Precision: 0.7271, Recall: 0.9376, F1 Score: 0.8167, AUC Score: 0.7745
#
# Validation: 	Fold 5 - Loss: 0.5498, Accuracy: 0.6979, Precision: 0.6612, Recall: 0.9347, F1 Score: 0.7583, AUC Score: 0.8136
#
# Epoch 34/150
# Training: 	Fold 1 - Loss: 0.6242, Accuracy: 0.6309, Precision: 0.6420, Recall: 0.7857, F1 Score: 0.7015, AUC Score: 0.7327
# Training: 	Fold 2 - Loss: 0.5635, Accuracy: 0.6875, Precision: 0.7312, Recall: 0.8339, F1 Score: 0.7676, AUC Score: 0.7565
#
# Validation: 	Fold 5 - Loss: 0.9125, Accuracy: 0.4349, Precision: 0.5000, Recall: 0.0259, F1 Score: 0.0491, AUC Score: 0.7431
#
# Epoch 35/150
# Training: 	Fold 1 - Loss: 0.5828, Accuracy: 0.6758, Precision: 0.6795, Recall: 0.8631, F1 Score: 0.7530, AUC Score: 0.7588
# Training: 	Fold 2 - Loss: 0.5783, Accuracy: 0.6777, Precision: 0.6866, Recall: 0.8764, F1 Score: 0.7619, AUC Score: 0.7814
# Training: 	Fold 3 - Loss: 0.5426, Accuracy: 0.7129, Precision: 0.7522, Recall: 0.8231, F1 Score: 0.7758, AUC Score: 0.7903
#
# Validation: 	Fold 5 - Loss: 0.4834, Accuracy: 0.7370, Precision: 0.7708, Recall: 0.6950, F1 Score: 0.7274, AUC Score: 0.8383
#
# Epoch 36/150
# Training: 	Fold 1 - Loss: 0.5886, Accuracy: 0.7070, Precision: 0.7359, Recall: 0.7989, F1 Score: 0.7630, AUC Score: 0.7358
# Training: 	Fold 2 - Loss: 0.5536, Accuracy: 0.6973, Precision: 0.7201, Recall: 0.8306, F1 Score: 0.7655, AUC Score: 0.7775
# Training: 	Fold 3 - Loss: 0.5431, Accuracy: 0.7168, Precision: 0.7491, Recall: 0.7976, F1 Score: 0.7691, AUC Score: 0.7757
# Training: 	Fold 4 - Loss: 0.4953, Accuracy: 0.7773, Precision: 0.7968, Recall: 0.8549, F1 Score: 0.8195, AUC Score: 0.8292
#
# Validation: 	Fold 5 - Loss: 0.4201, Accuracy: 0.7969, Precision: 0.7617, Recall: 0.8590, F1 Score: 0.8039, AUC Score: 0.8946
#
# Epoch 37/150
# Training: 	Fold 1 - Loss: 0.5491, Accuracy: 0.7461, Precision: 0.7280, Recall: 0.7961, F1 Score: 0.7585, AUC Score: 0.8080
# Training: 	Fold 2 - Loss: 0.5477, Accuracy: 0.7305, Precision: 0.7983, Recall: 0.7822, F1 Score: 0.7795, AUC Score: 0.8024
#
# Validation: 	Fold 5 - Loss: 0.6994, Accuracy: 0.6849, Precision: 0.6931, Recall: 0.7106, F1 Score: 0.6994, AUC Score: 0.7508
#
# Epoch 38/150
# Training: 	Fold 1 - Loss: 0.5196, Accuracy: 0.7578, Precision: 0.7781, Recall: 0.8262, F1 Score: 0.7983, AUC Score: 0.8094
# Training: 	Fold 3 - Loss: 0.4964, Accuracy: 0.7617, Precision: 0.7650, Recall: 0.8780, F1 Score: 0.8115, AUC Score: 0.8475
#
# Validation: 	Fold 5 - Loss: 0.8754, Accuracy: 0.6432, Precision: 0.6233, Recall: 0.9648, F1 Score: 0.7397, AUC Score: 0.7286
#
# Epoch 39/150
# Training: 	Fold 1 - Loss: 0.4713, Accuracy: 0.7559, Precision: 0.7794, Recall: 0.8424, F1 Score: 0.8023, AUC Score: 0.8581
# Training: 	Fold 2 - Loss: 0.4850, Accuracy: 0.7617, Precision: 0.8140, Recall: 0.8256, F1 Score: 0.8106, AUC Score: 0.8415
#
# Validation: 	Fold 5 - Loss: 0.4470, Accuracy: 0.7604, Precision: 0.7301, Recall: 0.9045, F1 Score: 0.7911, AUC Score: 0.8733
#
# Epoch 40/150
# Training: 	Fold 1 - Loss: 0.5440, Accuracy: 0.6738, Precision: 0.6763, Recall: 0.8090, F1 Score: 0.7328, AUC Score: 0.7993
# Training: 	Fold 2 - Loss: 0.5090, Accuracy: 0.7324, Precision: 0.7816, Recall: 0.8198, F1 Score: 0.7890, AUC Score: 0.8307
# Training: 	Fold 3 - Loss: 0.4778, Accuracy: 0.7695, Precision: 0.8147, Recall: 0.8370, F1 Score: 0.8128, AUC Score: 0.8572
#
# Validation: 	Fold 5 - Loss: 0.4601, Accuracy: 0.7422, Precision: 0.7041, Recall: 0.9108, F1 Score: 0.7828, AUC Score: 0.8741
#
# Epoch 41/150
# Training: 	Fold 1 - Loss: 0.4804, Accuracy: 0.7559, Precision: 0.7516, Recall: 0.8964, F1 Score: 0.8100, AUC Score: 0.8564
# Training: 	Fold 2 - Loss: 0.4799, Accuracy: 0.7891, Precision: 0.7991, Recall: 0.8858, F1 Score: 0.8339, AUC Score: 0.8573
#
# Validation: 	Fold 5 - Loss: 0.6243, Accuracy: 0.6328, Precision: 0.6496, Recall: 0.7655, F1 Score: 0.6867, AUC Score: 0.7033
#
# Epoch 42/150
# Training: 	Fold 1 - Loss: 0.6359, Accuracy: 0.6074, Precision: 0.6279, Recall: 0.7520, F1 Score: 0.6814, AUC Score: 0.6867
# Training: 	Fold 2 - Loss: 0.6169, Accuracy: 0.6445, Precision: 0.6751, Recall: 0.7396, F1 Score: 0.7046, AUC Score: 0.7158
# Training: 	Fold 3 - Loss: 0.5699, Accuracy: 0.7188, Precision: 0.7568, Recall: 0.8257, F1 Score: 0.7783, AUC Score: 0.7690
#
# Validation: 	Fold 5 - Loss: 0.5819, Accuracy: 0.7266, Precision: 0.6998, Recall: 0.8952, F1 Score: 0.7735, AUC Score: 0.7724
#
# Epoch 43/150
# Training: 	Fold 1 - Loss: 0.5228, Accuracy: 0.7598, Precision: 0.7589, Recall: 0.8827, F1 Score: 0.8106, AUC Score: 0.8108
# Training: 	Fold 2 - Loss: 0.5322, Accuracy: 0.7676, Precision: 0.7603, Recall: 0.9080, F1 Score: 0.8218, AUC Score: 0.8340
#
# Validation: 	Fold 5 - Loss: 0.5129, Accuracy: 0.6953, Precision: 0.7039, Recall: 0.7989, F1 Score: 0.7310, AUC Score: 0.8107
#
# Epoch 44/150
# Training: 	Fold 1 - Loss: 0.5934, Accuracy: 0.6855, Precision: 0.7116, Recall: 0.8088, F1 Score: 0.7490, AUC Score: 0.7586
# Training: 	Fold 2 - Loss: 0.6096, Accuracy: 0.6836, Precision: 0.7056, Recall: 0.8410, F1 Score: 0.7595, AUC Score: 0.7278
# Training: 	Fold 3 - Loss: 0.6015, Accuracy: 0.6816, Precision: 0.6844, Recall: 0.8735, F1 Score: 0.7627, AUC Score: 0.7576
# Training: 	Fold 4 - Loss: 0.5484, Accuracy: 0.7233, Precision: 0.7587, Recall: 0.8308, F1 Score: 0.7845, AUC Score: 0.7893
#
# Validation: 	Fold 5 - Loss: 1.0077, Accuracy: 0.6380, Precision: 0.6126, Recall: 1.0000, F1 Score: 0.7425, AUC Score: 0.8107
#
# Epoch 45/150
# Training: 	Fold 1 - Loss: 0.5656, Accuracy: 0.7129, Precision: 0.7191, Recall: 0.8113, F1 Score: 0.7592, AUC Score: 0.8166
# Training: 	Fold 2 - Loss: 0.5478, Accuracy: 0.7109, Precision: 0.7365, Recall: 0.8365, F1 Score: 0.7724, AUC Score: 0.7900
# Training: 	Fold 3 - Loss: 0.5208, Accuracy: 0.7695, Precision: 0.7651, Recall: 0.8882, F1 Score: 0.8170, AUC Score: 0.8063
#
# Validation: 	Fold 5 - Loss: 0.5078, Accuracy: 0.7630, Precision: 0.7142, Recall: 0.9659, F1 Score: 0.8070, AUC Score: 0.8565
# Model with best precision during Validation saved at epoch 45 with F1 Score of 0.8070
#
# Epoch 46/150
# Training: 	Fold 1 - Loss: 0.5713, Accuracy: 0.6895, Precision: 0.7388, Recall: 0.7863, F1 Score: 0.7513, AUC Score: 0.7467
# Training: 	Fold 2 - Loss: 0.5327, Accuracy: 0.7500, Precision: 0.7454, Recall: 0.8978, F1 Score: 0.8115, AUC Score: 0.7966
# Training: 	Fold 3 - Loss: 0.5074, Accuracy: 0.7676, Precision: 0.7607, Recall: 0.8962, F1 Score: 0.8181, AUC Score: 0.8194
# Training: 	Fold 4 - Loss: 0.5037, Accuracy: 0.7754, Precision: 0.7794, Recall: 0.8773, F1 Score: 0.8213, AUC Score: 0.8185
#
# Validation: 	Fold 5 - Loss: 0.3857, Accuracy: 0.8177, Precision: 0.7617, Recall: 0.9513, F1 Score: 0.8339, AUC Score: 0.9230
# Model with best precision during Validation saved at epoch 46 with F1 Score of 0.8339
#
# Epoch 47/150
# Training: 	Fold 1 - Loss: 0.5247, Accuracy: 0.7598, Precision: 0.7682, Recall: 0.8750, F1 Score: 0.8100, AUC Score: 0.8285
# Training: 	Fold 2 - Loss: 0.5108, Accuracy: 0.7656, Precision: 0.8017, Recall: 0.8555, F1 Score: 0.8163, AUC Score: 0.8361
#
# Validation: 	Fold 5 - Loss: 0.5186, Accuracy: 0.7448, Precision: 0.7724, Recall: 0.7584, F1 Score: 0.7564, AUC Score: 0.8213
#
# Epoch 48/150
# Training: 	Fold 1 - Loss: 0.5091, Accuracy: 0.7617, Precision: 0.7724, Recall: 0.8420, F1 Score: 0.8031, AUC Score: 0.8234
# Training: 	Fold 2 - Loss: 0.4423, Accuracy: 0.7988, Precision: 0.8286, Recall: 0.8442, F1 Score: 0.8321, AUC Score: 0.8649
#
# Validation: 	Fold 5 - Loss: 0.5631, Accuracy: 0.7422, Precision: 0.7664, Recall: 0.7571, F1 Score: 0.7569, AUC Score: 0.8423
#
# Epoch 49/150
# Training: 	Fold 1 - Loss: 0.4736, Accuracy: 0.7773, Precision: 0.7844, Recall: 0.8673, F1 Score: 0.8210, AUC Score: 0.8384
# Training: 	Fold 4 - Loss: 0.4310, Accuracy: 0.7923, Precision: 0.8396, Recall: 0.8516, F1 Score: 0.8328, AUC Score: 0.8885
#
# Validation: 	Fold 5 - Loss: 0.3788, Accuracy: 0.8359, Precision: 0.7738, Recall: 0.9212, F1 Score: 0.8397, AUC Score: 0.9216
# Model with best precision during Validation saved at epoch 49 with F1 Score of 0.8397
#
# Epoch 50/150
# Training: 	Fold 1 - Loss: 0.4045, Accuracy: 0.8125, Precision: 0.8065, Recall: 0.9118, F1 Score: 0.8513, AUC Score: 0.8850
# Training: 	Fold 2 - Loss: 0.4023, Accuracy: 0.8281, Precision: 0.8376, Recall: 0.8930, F1 Score: 0.8624, AUC Score: 0.8903
#
# Validation: 	Fold 5 - Loss: 0.4331, Accuracy: 0.7995, Precision: 0.7894, Recall: 0.8392, F1 Score: 0.8062, AUC Score: 0.8792
#
# Epoch 51/150
# Training: 	Fold 1 - Loss: 0.5204, Accuracy: 0.7305, Precision: 0.7299, Recall: 0.8350, F1 Score: 0.7718, AUC Score: 0.8583
# Training: 	Fold 2 - Loss: 0.4430, Accuracy: 0.7930, Precision: 0.7954, Recall: 0.8869, F1 Score: 0.8367, AUC Score: 0.8723
# Training: 	Fold 4 - Loss: 0.4070, Accuracy: 0.8164, Precision: 0.8317, Recall: 0.8752, F1 Score: 0.8495, AUC Score: 0.8830
#
# Validation: 	Fold 5 - Loss: 0.3148, Accuracy: 0.8411, Precision: 0.8074, Recall: 0.8910, F1 Score: 0.8411, AUC Score: 0.9434
# Model with best precision during Validation saved at epoch 51 with F1 Score of 0.8411
#
# Epoch 52/150
# Training: 	Fold 1 - Loss: 0.4153, Accuracy: 0.8320, Precision: 0.8431, Recall: 0.8809, F1 Score: 0.8571, AUC Score: 0.8865
#
# Validation: 	Fold 5 - Loss: 0.3943, Accuracy: 0.8359, Precision: 0.8415, Recall: 0.8228, F1 Score: 0.8301, AUC Score: 0.9082
#
# Epoch 53/150
# Training: 	Fold 1 - Loss: 0.5066, Accuracy: 0.7363, Precision: 0.7555, Recall: 0.7953, F1 Score: 0.7714, AUC Score: 0.8583
#
# Validation: 	Fold 5 - Loss: 0.6084, Accuracy: 0.6719, Precision: 0.6608, Recall: 0.9336, F1 Score: 0.7499, AUC Score: 0.7065
#
# Epoch 54/150
# Training: 	Fold 1 - Loss: 0.6187, Accuracy: 0.5840, Precision: 0.6047, Recall: 0.7847, F1 Score: 0.6783, AUC Score: 0.7087
# Training: 	Fold 2 - Loss: 0.5495, Accuracy: 0.7246, Precision: 0.7698, Recall: 0.7834, F1 Score: 0.7715, AUC Score: 0.7766
# Training: 	Fold 4 - Loss: 0.5104, Accuracy: 0.7272, Precision: 0.7431, Recall: 0.8261, F1 Score: 0.7751, AUC Score: 0.8111
#
# Validation: 	Fold 5 - Loss: 0.4570, Accuracy: 0.7891, Precision: 0.7949, Recall: 0.8069, F1 Score: 0.7982, AUC Score: 0.8593
#
# Epoch 55/150
# Training: 	Fold 1 - Loss: 0.5407, Accuracy: 0.7129, Precision: 0.7803, Recall: 0.7705, F1 Score: 0.7644, AUC Score: 0.7933
# Training: 	Fold 3 - Loss: 0.5295, Accuracy: 0.7461, Precision: 0.8052, Recall: 0.7693, F1 Score: 0.7783, AUC Score: 0.8006
#
# Validation: 	Fold 5 - Loss: 1.0949, Accuracy: 0.4818, Precision: 0.7500, Recall: 0.1158, F1 Score: 0.2003, AUC Score: 0.8392
#
# Epoch 56/150
# Training: 	Fold 1 - Loss: 0.5314, Accuracy: 0.7207, Precision: 0.7632, Recall: 0.8157, F1 Score: 0.7794, AUC Score: 0.7945
# Training: 	Fold 2 - Loss: 0.5230, Accuracy: 0.7598, Precision: 0.7624, Recall: 0.8726, F1 Score: 0.8100, AUC Score: 0.8072
#
# Validation: 	Fold 5 - Loss: 0.4676, Accuracy: 0.7708, Precision: 0.7675, Recall: 0.8437, F1 Score: 0.7987, AUC Score: 0.8735
#
# Epoch 57/150
# Training: 	Fold 1 - Loss: 0.5285, Accuracy: 0.7188, Precision: 0.7253, Recall: 0.8684, F1 Score: 0.7827, AUC Score: 0.8024
# Training: 	Fold 3 - Loss: 0.4878, Accuracy: 0.7930, Precision: 0.7956, Recall: 0.8790, F1 Score: 0.8330, AUC Score: 0.8363
#
# Validation: 	Fold 5 - Loss: 1.4319, Accuracy: 0.4583, Precision: 0.6875, Recall: 0.1034, F1 Score: 0.1657, AUC Score: 0.7872
#
# Epoch 58/150
# Training: 	Fold 1 - Loss: 0.4904, Accuracy: 0.7363, Precision: 0.7607, Recall: 0.7859, F1 Score: 0.7693, AUC Score: 0.8615
# Training: 	Fold 2 - Loss: 0.4223, Accuracy: 0.8184, Precision: 0.8401, Recall: 0.8662, F1 Score: 0.8503, AUC Score: 0.8812
#
# Validation: 	Fold 5 - Loss: 0.9533, Accuracy: 0.5859, Precision: 0.9000, Recall: 0.2918, F1 Score: 0.4309, AUC Score: 0.8187
#
# Epoch 59/150
# Training: 	Fold 1 - Loss: 0.5683, Accuracy: 0.7324, Precision: 0.7447, Recall: 0.8101, F1 Score: 0.7697, AUC Score: 0.8309
# Training: 	Fold 2 - Loss: 0.4761, Accuracy: 0.7871, Precision: 0.8331, Recall: 0.8576, F1 Score: 0.8320, AUC Score: 0.8637
# Training: 	Fold 4 - Loss: 0.4347, Accuracy: 0.8203, Precision: 0.8205, Recall: 0.9039, F1 Score: 0.8550, AUC Score: 0.8727
#
# Validation: 	Fold 5 - Loss: 0.5764, Accuracy: 0.7266, Precision: 0.9226, Recall: 0.5334, F1 Score: 0.6712, AUC Score: 0.9025
#
# Epoch 60/150
# Training: 	Fold 1 - Loss: 0.4564, Accuracy: 0.7637, Precision: 0.7947, Recall: 0.8520, F1 Score: 0.8108, AUC Score: 0.8653
# Training: 	Fold 2 - Loss: 0.4250, Accuracy: 0.8027, Precision: 0.8035, Recall: 0.9082, F1 Score: 0.8439, AUC Score: 0.8971
#
# Validation: 	Fold 5 - Loss: 0.8884, Accuracy: 0.6823, Precision: 0.8130, Recall: 0.5875, F1 Score: 0.6667, AUC Score: 0.7502
#
# Epoch 61/150
# Training: 	Fold 1 - Loss: 0.6091, Accuracy: 0.6953, Precision: 0.7113, Recall: 0.8347, F1 Score: 0.7614, AUC Score: 0.7304
# Training: 	Fold 2 - Loss: 0.5473, Accuracy: 0.7227, Precision: 0.7297, Recall: 0.8782, F1 Score: 0.7889, AUC Score: 0.7903
# Training: 	Fold 3 - Loss: 0.4998, Accuracy: 0.7754, Precision: 0.7774, Recall: 0.8837, F1 Score: 0.8219, AUC Score: 0.8369
#
# Validation: 	Fold 5 - Loss: 0.8748, Accuracy: 0.5469, Precision: 0.9375, Recall: 0.2288, F1 Score: 0.3618, AUC Score: 0.8238
#
# Epoch 62/150
# Training: 	Fold 1 - Loss: 0.4878, Accuracy: 0.7441, Precision: 0.7639, Recall: 0.8456, F1 Score: 0.7935, AUC Score: 0.8429
# Training: 	Fold 3 - Loss: 0.4677, Accuracy: 0.8105, Precision: 0.8058, Recall: 0.9067, F1 Score: 0.8503, AUC Score: 0.8547
#
# Validation: 	Fold 5 - Loss: 0.3425, Accuracy: 0.8516, Precision: 0.8110, Recall: 0.9191, F1 Score: 0.8592, AUC Score: 0.9321
# Model with best precision during Validation saved at epoch 62 with F1 Score of 0.8592
#
# Epoch 63/150
# Training: 	Fold 1 - Loss: 0.4683, Accuracy: 0.7734, Precision: 0.7808, Recall: 0.8803, F1 Score: 0.8195, AUC Score: 0.8680
# Training: 	Fold 2 - Loss: 0.4214, Accuracy: 0.8398, Precision: 0.8558, Recall: 0.8887, F1 Score: 0.8695, AUC Score: 0.8865
#
# Validation: 	Fold 5 - Loss: 0.3162, Accuracy: 0.8646, Precision: 0.8288, Recall: 0.9027, F1 Score: 0.8610, AUC Score: 0.9369
# Model with best precision during Validation saved at epoch 63 with F1 Score of 0.8610
#
# Epoch 64/150
# Training: 	Fold 1 - Loss: 0.4851, Accuracy: 0.7559, Precision: 0.7688, Recall: 0.8198, F1 Score: 0.7865, AUC Score: 0.8730
# Training: 	Fold 2 - Loss: 0.4531, Accuracy: 0.8105, Precision: 0.8053, Recall: 0.8161, F1 Score: 0.8079, AUC Score: 0.8862
#
# Validation: 	Fold 5 - Loss: 0.3757, Accuracy: 0.8359, Precision: 0.8074, Recall: 0.9034, F1 Score: 0.8471, AUC Score: 0.9236
#
# Epoch 65/150
# Training: 	Fold 1 - Loss: 0.4865, Accuracy: 0.7539, Precision: 0.7867, Recall: 0.8498, F1 Score: 0.8083, AUC Score: 0.8603
# Training: 	Fold 2 - Loss: 0.4853, Accuracy: 0.7812, Precision: 0.7806, Recall: 0.9111, F1 Score: 0.8320, AUC Score: 0.8688
# Training: 	Fold 3 - Loss: 0.4319, Accuracy: 0.8047, Precision: 0.8123, Recall: 0.8813, F1 Score: 0.8387, AUC Score: 0.8593
# Training: 	Fold 4 - Loss: 0.4509, Accuracy: 0.7995, Precision: 0.8151, Recall: 0.8868, F1 Score: 0.8439, AUC Score: 0.8795
#
# Validation: 	Fold 5 - Loss: 0.3769, Accuracy: 0.7943, Precision: 0.7520, Recall: 0.9262, F1 Score: 0.8185, AUC Score: 0.9187
#
# Epoch 66/150
# Training: 	Fold 1 - Loss: 0.5452, Accuracy: 0.7227, Precision: 0.7430, Recall: 0.8402, F1 Score: 0.7831, AUC Score: 0.7994
# Training: 	Fold 3 - Loss: 0.4277, Accuracy: 0.8184, Precision: 0.8016, Recall: 0.8292, F1 Score: 0.8129, AUC Score: 0.9170
#
# Validation: 	Fold 5 - Loss: 0.3398, Accuracy: 0.8438, Precision: 0.7907, Recall: 0.9513, F1 Score: 0.8520, AUC Score: 0.9284
#
# Epoch 67/150
# Training: 	Fold 1 - Loss: 0.4469, Accuracy: 0.8066, Precision: 0.7774, Recall: 0.8416, F1 Score: 0.8052, AUC Score: 0.8949
# Training: 	Fold 3 - Loss: 0.4461, Accuracy: 0.8047, Precision: 0.8577, Recall: 0.8399, F1 Score: 0.8394, AUC Score: 0.9022
#
# Validation: 	Fold 5 - Loss: 0.3404, Accuracy: 0.8333, Precision: 0.7810, Recall: 0.9180, F1 Score: 0.8382, AUC Score: 0.9383
#
# Epoch 68/150
# Training: 	Fold 1 - Loss: 0.4951, Accuracy: 0.7324, Precision: 0.7312, Recall: 0.8362, F1 Score: 0.7735, AUC Score: 0.8592
# Training: 	Fold 3 - Loss: 0.4817, Accuracy: 0.7559, Precision: 0.7547, Recall: 0.8424, F1 Score: 0.7912, AUC Score: 0.8688
#
# Validation: 	Fold 5 - Loss: 0.3350, Accuracy: 0.8490, Precision: 0.8072, Recall: 0.9056, F1 Score: 0.8457, AUC Score: 0.9332
#
# Epoch 69/150
# Training: 	Fold 1 - Loss: 0.4305, Accuracy: 0.8086, Precision: 0.8655, Recall: 0.8368, F1 Score: 0.8436, AUC Score: 0.8941
#
# Validation: 	Fold 5 - Loss: 0.3253, Accuracy: 0.8828, Precision: 0.8416, Recall: 0.9059, F1 Score: 0.8705, AUC Score: 0.9332
# Model with best precision during Validation saved at epoch 69 with F1 Score of 0.8705
#
# Epoch 70/150
# Training: 	Fold 1 - Loss: 0.3873, Accuracy: 0.8438, Precision: 0.8497, Recall: 0.9018, F1 Score: 0.8693, AUC Score: 0.8982
#
# Validation: 	Fold 5 - Loss: 0.3790, Accuracy: 0.8203, Precision: 0.7649, Recall: 0.9297, F1 Score: 0.8315, AUC Score: 0.9238
#
# Epoch 71/150
# Training: 	Fold 1 - Loss: 0.4134, Accuracy: 0.8379, Precision: 0.8315, Recall: 0.9171, F1 Score: 0.8681, AUC Score: 0.8903
#
# Validation: 	Fold 5 - Loss: 0.7549, Accuracy: 0.5807, Precision: 0.8810, Recall: 0.2879, F1 Score: 0.4283, AUC Score: 0.8264
#
# Epoch 72/150
# Training: 	Fold 1 - Loss: 0.4530, Accuracy: 0.7773, Precision: 0.7987, Recall: 0.8812, F1 Score: 0.8264, AUC Score: 0.8875
# Training: 	Fold 2 - Loss: 0.3921, Accuracy: 0.8008, Precision: 0.8122, Recall: 0.8995, F1 Score: 0.8448, AUC Score: 0.9047
#
# Validation: 	Fold 5 - Loss: 0.3357, Accuracy: 0.8490, Precision: 0.8323, Recall: 0.8392, F1 Score: 0.8349, AUC Score: 0.9372
#
# Epoch 73/150
# Training: 	Fold 1 - Loss: 0.4430, Accuracy: 0.8164, Precision: 0.8200, Recall: 0.9116, F1 Score: 0.8545, AUC Score: 0.9035
#
# Validation: 	Fold 5 - Loss: 0.3209, Accuracy: 0.8620, Precision: 0.8116, Recall: 0.9223, F1 Score: 0.8606, AUC Score: 0.9551
#
# Epoch 74/150
# Training: 	Fold 1 - Loss: 0.4582, Accuracy: 0.7812, Precision: 0.7598, Recall: 0.8228, F1 Score: 0.7862, AUC Score: 0.8786
# Training: 	Fold 2 - Loss: 0.4020, Accuracy: 0.8105, Precision: 0.8475, Recall: 0.8638, F1 Score: 0.8465, AUC Score: 0.9047
# Training: 	Fold 3 - Loss: 0.3968, Accuracy: 0.8438, Precision: 0.8640, Recall: 0.8803, F1 Score: 0.8669, AUC Score: 0.8911
# Training: 	Fold 4 - Loss: 0.3651, Accuracy: 0.8457, Precision: 0.8519, Recall: 0.9047, F1 Score: 0.8726, AUC Score: 0.9079
#
# Validation: 	Fold 5 - Loss: 0.2565, Accuracy: 0.9010, Precision: 0.8954, Recall: 0.9034, F1 Score: 0.8966, AUC Score: 0.9665
# Model with best precision during Validation saved at epoch 74 with F1 Score of 0.8966
#
# Epoch 75/150
# Training: 	Fold 1 - Loss: 0.4314, Accuracy: 0.7676, Precision: 0.7873, Recall: 0.8073, F1 Score: 0.7954, AUC Score: 0.9037
# Training: 	Fold 2 - Loss: 0.4048, Accuracy: 0.8281, Precision: 0.8588, Recall: 0.8588, F1 Score: 0.8530, AUC Score: 0.8989
# Training: 	Fold 3 - Loss: 0.4005, Accuracy: 0.8242, Precision: 0.8551, Recall: 0.8868, F1 Score: 0.8611, AUC Score: 0.9214
#
# Validation: 	Fold 5 - Loss: 0.2987, Accuracy: 0.8672, Precision: 0.8338, Recall: 0.9127, F1 Score: 0.8661, AUC Score: 0.9534
#
# Epoch 76/150
# Training: 	Fold 1 - Loss: 0.4528, Accuracy: 0.7715, Precision: 0.7722, Recall: 0.8458, F1 Score: 0.8030, AUC Score: 0.9065
# Training: 	Fold 4 - Loss: 0.4677, Accuracy: 0.7897, Precision: 0.8016, Recall: 0.8798, F1 Score: 0.8336, AUC Score: 0.8683
#
# Validation: 	Fold 5 - Loss: 0.3879, Accuracy: 0.8125, Precision: 0.8042, Recall: 0.8228, F1 Score: 0.8085, AUC Score: 0.9011
#
# Epoch 77/150
# Training: 	Fold 1 - Loss: 0.4803, Accuracy: 0.7520, Precision: 0.8001, Recall: 0.8214, F1 Score: 0.7988, AUC Score: 0.8472
# Training: 	Fold 2 - Loss: 0.4711, Accuracy: 0.7676, Precision: 0.8169, Recall: 0.8340, F1 Score: 0.8159, AUC Score: 0.8516
# Training: 	Fold 3 - Loss: 0.4547, Accuracy: 0.7754, Precision: 0.7680, Recall: 0.9028, F1 Score: 0.8251, AUC Score: 0.8822
# Training: 	Fold 4 - Loss: 0.4550, Accuracy: 0.7852, Precision: 0.8009, Recall: 0.8595, F1 Score: 0.8259, AUC Score: 0.8450
#
# Validation: 	Fold 5 - Loss: 0.4435, Accuracy: 0.8073, Precision: 0.7535, Recall: 0.9815, F1 Score: 0.8347, AUC Score: 0.8869
#
# Epoch 78/150
# Training: 	Fold 1 - Loss: 0.4366, Accuracy: 0.7891, Precision: 0.7955, Recall: 0.8749, F1 Score: 0.8270, AUC Score: 0.8553
# Training: 	Fold 2 - Loss: 0.4288, Accuracy: 0.8262, Precision: 0.8377, Recall: 0.8939, F1 Score: 0.8594, AUC Score: 0.8777
# Training: 	Fold 3 - Loss: 0.3988, Accuracy: 0.8359, Precision: 0.8267, Recall: 0.9184, F1 Score: 0.8668, AUC Score: 0.8969
#
# Validation: 	Fold 5 - Loss: 0.2518, Accuracy: 0.8672, Precision: 0.8286, Recall: 0.9357, F1 Score: 0.8763, AUC Score: 0.9659
#
# Epoch 79/150
# Training: 	Fold 1 - Loss: 0.4976, Accuracy: 0.7598, Precision: 0.7713, Recall: 0.8586, F1 Score: 0.8074, AUC Score: 0.8514
# Training: 	Fold 4 - Loss: 0.4426, Accuracy: 0.8086, Precision: 0.8059, Recall: 0.8975, F1 Score: 0.8439, AUC Score: 0.8675
#
# Validation: 	Fold 5 - Loss: 0.3028, Accuracy: 0.8698, Precision: 0.8038, Recall: 0.9606, F1 Score: 0.8718, AUC Score: 0.9673
#
# Epoch 80/150
# Training: 	Fold 1 - Loss: 0.4362, Accuracy: 0.7812, Precision: 0.7916, Recall: 0.8721, F1 Score: 0.8232, AUC Score: 0.8905
# Training: 	Fold 4 - Loss: 0.4058, Accuracy: 0.8210, Precision: 0.8313, Recall: 0.8817, F1 Score: 0.8474, AUC Score: 0.9085
#
# Validation: 	Fold 5 - Loss: 0.2981, Accuracy: 0.8620, Precision: 0.8283, Recall: 0.9265, F1 Score: 0.8702, AUC Score: 0.9500
#
# Epoch 81/150
# Training: 	Fold 1 - Loss: 0.4309, Accuracy: 0.7949, Precision: 0.8560, Recall: 0.8246, F1 Score: 0.8300, AUC Score: 0.8881
# Training: 	Fold 2 - Loss: 0.4393, Accuracy: 0.8125, Precision: 0.8512, Recall: 0.8671, F1 Score: 0.8498, AUC Score: 0.8808
#
# Validation: 	Fold 5 - Loss: 0.3574, Accuracy: 0.8385, Precision: 0.8042, Recall: 0.9201, F1 Score: 0.8483, AUC Score: 0.9247
#
# Epoch 82/150
# Training: 	Fold 1 - Loss: 0.5616, Accuracy: 0.7285, Precision: 0.7791, Recall: 0.8119, F1 Score: 0.7822, AUC Score: 0.7852
# Training: 	Fold 2 - Loss: 0.5035, Accuracy: 0.7441, Precision: 0.7813, Recall: 0.8400, F1 Score: 0.7982, AUC Score: 0.8203
# Training: 	Fold 3 - Loss: 0.4641, Accuracy: 0.7891, Precision: 0.7751, Recall: 0.9298, F1 Score: 0.8386, AUC Score: 0.8804
#
# Validation: 	Fold 5 - Loss: 0.3863, Accuracy: 0.8255, Precision: 0.7842, Recall: 0.9201, F1 Score: 0.8419, AUC Score: 0.9136
#
# Epoch 83/150
# Training: 	Fold 1 - Loss: 0.4490, Accuracy: 0.7852, Precision: 0.8024, Recall: 0.8753, F1 Score: 0.8265, AUC Score: 0.8775
# Training: 	Fold 2 - Loss: 0.4010, Accuracy: 0.8398, Precision: 0.8601, Recall: 0.8817, F1 Score: 0.8652, AUC Score: 0.8947
# Training: 	Fold 3 - Loss: 0.3720, Accuracy: 0.8438, Precision: 0.8382, Recall: 0.9176, F1 Score: 0.8722, AUC Score: 0.9074
#
# Validation: 	Fold 5 - Loss: 0.2731, Accuracy: 0.8880, Precision: 0.8824, Recall: 0.8918, F1 Score: 0.8794, AUC Score: 0.9537
#
# Epoch 84/150
# Training: 	Fold 1 - Loss: 0.4050, Accuracy: 0.8047, Precision: 0.8520, Recall: 0.8464, F1 Score: 0.8422, AUC Score: 0.8964
#
# Validation: 	Fold 5 - Loss: 0.3889, Accuracy: 0.8229, Precision: 0.7978, Recall: 0.9016, F1 Score: 0.8430, AUC Score: 0.9133
#
# Epoch 85/150
# Training: 	Fold 1 - Loss: 0.4964, Accuracy: 0.7676, Precision: 0.7752, Recall: 0.8206, F1 Score: 0.7934, AUC Score: 0.8801
# Training: 	Fold 2 - Loss: 0.3845, Accuracy: 0.8496, Precision: 0.8549, Recall: 0.9138, F1 Score: 0.8791, AUC Score: 0.9059
#
# Validation: 	Fold 5 - Loss: 0.2739, Accuracy: 0.8906, Precision: 0.8458, Recall: 0.9588, F1 Score: 0.8917, AUC Score: 0.9528
#
# Epoch 86/150
# Training: 	Fold 1 - Loss: 0.4041, Accuracy: 0.8027, Precision: 0.8503, Recall: 0.8511, F1 Score: 0.8394, AUC Score: 0.8955
# Training: 	Fold 2 - Loss: 0.3725, Accuracy: 0.8496, Precision: 0.8632, Recall: 0.8948, F1 Score: 0.8760, AUC Score: 0.9099
#
# Validation: 	Fold 5 - Loss: 0.2566, Accuracy: 0.8932, Precision: 0.8333, Recall: 0.9606, F1 Score: 0.8897, AUC Score: 0.9747
#
# Epoch 87/150
# Training: 	Fold 1 - Loss: 0.5726, Accuracy: 0.7715, Precision: 0.7688, Recall: 0.8395, F1 Score: 0.7976, AUC Score: 0.8839
# Training: 	Fold 2 - Loss: 0.4077, Accuracy: 0.8262, Precision: 0.8054, Recall: 0.8506, F1 Score: 0.8222, AUC Score: 0.9146
# Training: 	Fold 4 - Loss: 0.4123, Accuracy: 0.8242, Precision: 0.8413, Recall: 0.8769, F1 Score: 0.8570, AUC Score: 0.8944
#
# Validation: 	Fold 5 - Loss: 0.3344, Accuracy: 0.8880, Precision: 0.8274, Recall: 0.9907, F1 Score: 0.8916, AUC Score: 0.9480
#
# Epoch 88/150
# Training: 	Fold 1 - Loss: 0.4174, Accuracy: 0.7988, Precision: 0.7869, Recall: 0.8696, F1 Score: 0.8235, AUC Score: 0.9210
# Training: 	Fold 2 - Loss: 0.3999, Accuracy: 0.8047, Precision: 0.8518, Recall: 0.8516, F1 Score: 0.8434, AUC Score: 0.9033
# Training: 	Fold 3 - Loss: 0.4296, Accuracy: 0.8008, Precision: 0.7816, Recall: 0.9339, F1 Score: 0.8444, AUC Score: 0.8988
#
# Validation: 	Fold 5 - Loss: 0.3268, Accuracy: 0.8620, Precision: 0.8012, Recall: 0.9741, F1 Score: 0.8754, AUC Score: 0.9412
#
# Epoch 89/150
# Training: 	Fold 1 - Loss: 0.4442, Accuracy: 0.7832, Precision: 0.8075, Recall: 0.8754, F1 Score: 0.8286, AUC Score: 0.8694
# Training: 	Fold 3 - Loss: 0.3594, Accuracy: 0.8652, Precision: 0.8676, Recall: 0.9150, F1 Score: 0.8867, AUC Score: 0.9223
#
# Validation: 	Fold 5 - Loss: 0.2701, Accuracy: 0.8984, Precision: 0.8379, Recall: 0.9833, F1 Score: 0.8992, AUC Score: 0.9571
# Model with best precision during Validation saved at epoch 89 with F1 Score of 0.8992
#
# Epoch 90/150
# Training: 	Fold 1 - Loss: 0.3398, Accuracy: 0.8711, Precision: 0.8817, Recall: 0.9176, F1 Score: 0.8950, AUC Score: 0.9316
#
# Validation: 	Fold 5 - Loss: 0.2521, Accuracy: 0.9115, Precision: 0.8795, Recall: 0.9223, F1 Score: 0.8977, AUC Score: 0.9628
#
# Epoch 91/150
# Training: 	Fold 1 - Loss: 0.4830, Accuracy: 0.7676, Precision: 0.8017, Recall: 0.8141, F1 Score: 0.8032, AUC Score: 0.8342
# Training: 	Fold 2 - Loss: 0.4145, Accuracy: 0.8047, Precision: 0.8037, Recall: 0.9110, F1 Score: 0.8479, AUC Score: 0.8841
#
# Validation: 	Fold 5 - Loss: 0.3556, Accuracy: 0.8281, Precision: 0.8226, Recall: 0.8785, F1 Score: 0.8413, AUC Score: 0.9153
#
# Epoch 92/150
# Training: 	Fold 1 - Loss: 0.4565, Accuracy: 0.7461, Precision: 0.8015, Recall: 0.8025, F1 Score: 0.7912, AUC Score: 0.8684
# Training: 	Fold 2 - Loss: 0.4693, Accuracy: 0.8066, Precision: 0.8000, Recall: 0.9124, F1 Score: 0.8476, AUC Score: 0.8471
#
# Validation: 	Fold 5 - Loss: 0.4229, Accuracy: 0.7682, Precision: 0.7377, Recall: 0.8849, F1 Score: 0.7986, AUC Score: 0.8775
#
# Epoch 93/150
# Training: 	Fold 1 - Loss: 0.4395, Accuracy: 0.8125, Precision: 0.8150, Recall: 0.8963, F1 Score: 0.8480, AUC Score: 0.8716
# Training: 	Fold 2 - Loss: 0.4300, Accuracy: 0.8203, Precision: 0.8308, Recall: 0.8920, F1 Score: 0.8549, AUC Score: 0.8765
#
# Validation: 	Fold 5 - Loss: 0.2683, Accuracy: 0.8802, Precision: 0.8352, Recall: 0.9347, F1 Score: 0.8801, AUC Score: 0.9611
#
# Epoch 94/150
# Training: 	Fold 1 - Loss: 0.3997, Accuracy: 0.8164, Precision: 0.8391, Recall: 0.8610, F1 Score: 0.8472, AUC Score: 0.8837
# Training: 	Fold 4 - Loss: 0.3830, Accuracy: 0.8236, Precision: 0.8470, Recall: 0.8713, F1 Score: 0.8562, AUC Score: 0.9358
#
# Validation: 	Fold 5 - Loss: 0.2378, Accuracy: 0.8672, Precision: 0.8252, Recall: 0.9418, F1 Score: 0.8765, AUC Score: 0.9702
#
# Epoch 95/150
# Training: 	Fold 1 - Loss: 0.4562, Accuracy: 0.7773, Precision: 0.7869, Recall: 0.8264, F1 Score: 0.8027, AUC Score: 0.8898
# Training: 	Fold 2 - Loss: 0.3967, Accuracy: 0.8008, Precision: 0.8449, Recall: 0.8596, F1 Score: 0.8412, AUC Score: 0.9039
# Training: 	Fold 3 - Loss: 0.3929, Accuracy: 0.8242, Precision: 0.8518, Recall: 0.8827, F1 Score: 0.8580, AUC Score: 0.9109
#
# Validation: 	Fold 5 - Loss: 0.3137, Accuracy: 0.8490, Precision: 0.7988, Recall: 0.9357, F1 Score: 0.8569, AUC Score: 0.9437
#
# Epoch 96/150
# Training: 	Fold 1 - Loss: 0.4469, Accuracy: 0.8125, Precision: 0.8320, Recall: 0.8659, F1 Score: 0.8441, AUC Score: 0.8666
# Training: 	Fold 2 - Loss: 0.4171, Accuracy: 0.8203, Precision: 0.8447, Recall: 0.8694, F1 Score: 0.8505, AUC Score: 0.8783
# Training: 	Fold 3 - Loss: 0.3907, Accuracy: 0.8652, Precision: 0.8811, Recall: 0.8985, F1 Score: 0.8869, AUC Score: 0.9034
#
# Validation: 	Fold 5 - Loss: 0.2648, Accuracy: 0.9115, Precision: 0.8567, Recall: 0.9907, F1 Score: 0.9153, AUC Score: 0.9682
# Model with best precision during Validation saved at epoch 96 with F1 Score of 0.9153
#
# Epoch 97/150
# Training: 	Fold 1 - Loss: 0.3731, Accuracy: 0.8242, Precision: 0.8571, Recall: 0.8755, F1 Score: 0.8568, AUC Score: 0.9143
# Training: 	Fold 2 - Loss: 0.3008, Accuracy: 0.8848, Precision: 0.8823, Recall: 0.9361, F1 Score: 0.9072, AUC Score: 0.9439
#
# Validation: 	Fold 5 - Loss: 0.2796, Accuracy: 0.8880, Precision: 0.8534, Recall: 0.9584, F1 Score: 0.8956, AUC Score: 0.9540
#
# Epoch 98/150
# Training: 	Fold 1 - Loss: 0.3783, Accuracy: 0.8359, Precision: 0.8235, Recall: 0.9398, F1 Score: 0.8712, AUC Score: 0.9146
#
# Validation: 	Fold 5 - Loss: 0.3265, Accuracy: 0.8672, Precision: 0.8009, Recall: 0.9907, F1 Score: 0.8786, AUC Score: 0.9537
#
# Epoch 99/150
# Training: 	Fold 1 - Loss: 0.4669, Accuracy: 0.7578, Precision: 0.7644, Recall: 0.8292, F1 Score: 0.7910, AUC Score: 0.8825
# Training: 	Fold 2 - Loss: 0.4232, Accuracy: 0.7988, Precision: 0.8221, Recall: 0.8672, F1 Score: 0.8359, AUC Score: 0.8959
# Training: 	Fold 4 - Loss: 0.3820, Accuracy: 0.8346, Precision: 0.8730, Recall: 0.8682, F1 Score: 0.8660, AUC Score: 0.9175
#
# Validation: 	Fold 5 - Loss: 0.2220, Accuracy: 0.9115, Precision: 0.8709, Recall: 0.9751, F1 Score: 0.9137, AUC Score: 0.9827
#
# Epoch 100/150
# Training: 	Fold 1 - Loss: 0.3191, Accuracy: 0.8691, Precision: 0.8680, Recall: 0.9241, F1 Score: 0.8925, AUC Score: 0.9399
#
# Validation: 	Fold 5 - Loss: 0.2041, Accuracy: 0.9167, Precision: 0.8958, Recall: 0.9283, F1 Score: 0.9114, AUC Score: 0.9801
#
# Epoch 101/150
# Training: 	Fold 1 - Loss: 0.4547, Accuracy: 0.8164, Precision: 0.8304, Recall: 0.8743, F1 Score: 0.8486, AUC Score: 0.8597
# Training: 	Fold 2 - Loss: 0.3811, Accuracy: 0.8242, Precision: 0.8522, Recall: 0.8687, F1 Score: 0.8556, AUC Score: 0.9009
# Training: 	Fold 3 - Loss: 0.3542, Accuracy: 0.8652, Precision: 0.8690, Recall: 0.9202, F1 Score: 0.8894, AUC Score: 0.9287
#
# Validation: 	Fold 5 - Loss: 0.3222, Accuracy: 0.8620, Precision: 0.8220, Recall: 0.9194, F1 Score: 0.8636, AUC Score: 0.9341
#
# Epoch 102/150
# Training: 	Fold 1 - Loss: 0.4191, Accuracy: 0.7930, Precision: 0.8429, Recall: 0.8457, F1 Score: 0.8326, AUC Score: 0.8971
# Training: 	Fold 2 - Loss: 0.3360, Accuracy: 0.8574, Precision: 0.8588, Recall: 0.9186, F1 Score: 0.8855, AUC Score: 0.9235
#
# Validation: 	Fold 5 - Loss: 0.2748, Accuracy: 0.8854, Precision: 0.8134, Recall: 1.0000, F1 Score: 0.8910, AUC Score: 0.9668
#
# Epoch 103/150
# Training: 	Fold 1 - Loss: 0.4698, Accuracy: 0.8105, Precision: 0.7776, Recall: 0.8463, F1 Score: 0.8059, AUC Score: 0.9023
# Training: 	Fold 2 - Loss: 0.3580, Accuracy: 0.8633, Precision: 0.8716, Recall: 0.9038, F1 Score: 0.8855, AUC Score: 0.9187
# Training: 	Fold 3 - Loss: 0.3523, Accuracy: 0.8633, Precision: 0.8635, Recall: 0.9166, F1 Score: 0.8856, AUC Score: 0.9183
#
# Validation: 	Fold 5 - Loss: 0.2294, Accuracy: 0.9115, Precision: 0.8850, Recall: 0.9347, F1 Score: 0.9082, AUC Score: 0.9665
#
# Epoch 104/150
# Training: 	Fold 1 - Loss: 0.3528, Accuracy: 0.8359, Precision: 0.8479, Recall: 0.8870, F1 Score: 0.8607, AUC Score: 0.9154
# Training: 	Fold 3 - Loss: 0.3957, Accuracy: 0.8281, Precision: 0.8427, Recall: 0.9125, F1 Score: 0.8660, AUC Score: 0.9099
#
# Validation: 	Fold 5 - Loss: 0.2256, Accuracy: 0.8958, Precision: 0.8718, Recall: 0.9120, F1 Score: 0.8908, AUC Score: 0.9710
#
# Epoch 105/150
# Training: 	Fold 1 - Loss: 0.4439, Accuracy: 0.8301, Precision: 0.7913, Recall: 0.8625, F1 Score: 0.8224, AUC Score: 0.9157
# Training: 	Fold 2 - Loss: 0.3572, Accuracy: 0.8398, Precision: 0.8187, Recall: 0.8500, F1 Score: 0.8325, AUC Score: 0.9353
# Training: 	Fold 3 - Loss: 0.3471, Accuracy: 0.8438, Precision: 0.8932, Recall: 0.8726, F1 Score: 0.8724, AUC Score: 0.9352
# Training: 	Fold 4 - Loss: 0.3549, Accuracy: 0.8542, Precision: 0.8894, Recall: 0.8843, F1 Score: 0.8819, AUC Score: 0.9375
#
# Validation: 	Fold 5 - Loss: 0.2210, Accuracy: 0.9141, Precision: 0.8641, Recall: 0.9606, F1 Score: 0.9076, AUC Score: 0.9758
#
# Epoch 106/150
# Training: 	Fold 1 - Loss: 0.3132, Accuracy: 0.8730, Precision: 0.8637, Recall: 0.9285, F1 Score: 0.8923, AUC Score: 0.9324
# Training: 	Fold 3 - Loss: 0.3056, Accuracy: 0.8730, Precision: 0.9086, Recall: 0.9066, F1 Score: 0.9005, AUC Score: 0.9509
#
# Validation: 	Fold 5 - Loss: 0.1644, Accuracy: 0.9245, Precision: 0.8980, Recall: 0.9741, F1 Score: 0.9339, AUC Score: 0.9906
# Model with best precision during Validation saved at epoch 106 with F1 Score of 0.9339
#
# Epoch 107/150
# Training: 	Fold 1 - Loss: 0.3880, Accuracy: 0.8477, Precision: 0.8815, Recall: 0.8932, F1 Score: 0.8789, AUC Score: 0.9320
# Training: 	Fold 2 - Loss: 0.3143, Accuracy: 0.8691, Precision: 0.8833, Recall: 0.9115, F1 Score: 0.8938, AUC Score: 0.9348
#
# Validation: 	Fold 5 - Loss: 0.3058, Accuracy: 0.8724, Precision: 0.8313, Recall: 0.9223, F1 Score: 0.8738, AUC Score: 0.9466
#
# Epoch 108/150
# Training: 	Fold 1 - Loss: 0.3869, Accuracy: 0.8184, Precision: 0.8626, Recall: 0.8604, F1 Score: 0.8517, AUC Score: 0.9053
# Training: 	Fold 2 - Loss: 0.3458, Accuracy: 0.8379, Precision: 0.8833, Recall: 0.8797, F1 Score: 0.8728, AUC Score: 0.9327
# Training: 	Fold 3 - Loss: 0.3597, Accuracy: 0.8652, Precision: 0.8487, Recall: 0.9440, F1 Score: 0.8920, AUC Score: 0.9162
# Training: 	Fold 4 - Loss: 0.2999, Accuracy: 0.8789, Precision: 0.8655, Recall: 0.9464, F1 Score: 0.9013, AUC Score: 0.9472
#
# Validation: 	Fold 5 - Loss: 0.2662, Accuracy: 0.8646, Precision: 0.8111, Recall: 0.9286, F1 Score: 0.8620, AUC Score: 0.9639
#
# Epoch 109/150
# Training: 	Fold 1 - Loss: 0.4291, Accuracy: 0.8184, Precision: 0.8278, Recall: 0.9016, F1 Score: 0.8549, AUC Score: 0.9058
#
# Validation: 	Fold 5 - Loss: 0.4447, Accuracy: 0.8151, Precision: 0.8195, Recall: 0.8249, F1 Score: 0.8164, AUC Score: 0.8778
#
# Epoch 110/150
# Training: 	Fold 1 - Loss: 0.5497, Accuracy: 0.7422, Precision: 0.7410, Recall: 0.8364, F1 Score: 0.7815, AUC Score: 0.8328
# Training: 	Fold 2 - Loss: 0.4679, Accuracy: 0.7910, Precision: 0.7924, Recall: 0.9019, F1 Score: 0.8357, AUC Score: 0.8659
# Training: 	Fold 3 - Loss: 0.4144, Accuracy: 0.8555, Precision: 0.8533, Recall: 0.9222, F1 Score: 0.8826, AUC Score: 0.8941
#
# Validation: 	Fold 5 - Loss: 0.3012, Accuracy: 0.8984, Precision: 0.8636, Recall: 0.9584, F1 Score: 0.9068, AUC Score: 0.9466
#
# Epoch 111/150
# Training: 	Fold 1 - Loss: 0.3756, Accuracy: 0.8613, Precision: 0.8693, Recall: 0.9019, F1 Score: 0.8843, AUC Score: 0.9128
# Training: 	Fold 2 - Loss: 0.3519, Accuracy: 0.8691, Precision: 0.8844, Recall: 0.9046, F1 Score: 0.8905, AUC Score: 0.9208
#
# Validation: 	Fold 5 - Loss: 0.2688, Accuracy: 0.9036, Precision: 0.8615, Recall: 0.9513, F1 Score: 0.9013, AUC Score: 0.9602
#
# Epoch 112/150
# Training: 	Fold 1 - Loss: 0.3631, Accuracy: 0.8613, Precision: 0.8770, Recall: 0.8888, F1 Score: 0.8810, AUC Score: 0.9096
# Training: 	Fold 4 - Loss: 0.3798, Accuracy: 0.8522, Precision: 0.8804, Recall: 0.8949, F1 Score: 0.8834, AUC Score: 0.9161
#
# Validation: 	Fold 5 - Loss: 0.3194, Accuracy: 0.8490, Precision: 0.8258, Recall: 0.8963, F1 Score: 0.8493, AUC Score: 0.9375
#
# Epoch 113/150
# Training: 	Fold 1 - Loss: 0.3857, Accuracy: 0.8301, Precision: 0.8279, Recall: 0.9017, F1 Score: 0.8585, AUC Score: 0.8999
# Training: 	Fold 2 - Loss: 0.3063, Accuracy: 0.8770, Precision: 0.8658, Recall: 0.9373, F1 Score: 0.8988, AUC Score: 0.9345
#
# Validation: 	Fold 5 - Loss: 0.2219, Accuracy: 0.9115, Precision: 0.8603, Recall: 0.9667, F1 Score: 0.9058, AUC Score: 0.9761
#
# Epoch 114/150
# Training: 	Fold 1 - Loss: 0.2919, Accuracy: 0.8613, Precision: 0.8804, Recall: 0.9124, F1 Score: 0.8892, AUC Score: 0.9567
#
# Validation: 	Fold 5 - Loss: 0.2827, Accuracy: 0.9010, Precision: 0.8778, Recall: 0.9418, F1 Score: 0.9074, AUC Score: 0.9494
#
# Epoch 115/150
# Training: 	Fold 1 - Loss: 0.3517, Accuracy: 0.8340, Precision: 0.8443, Recall: 0.9047, F1 Score: 0.8657, AUC Score: 0.9390
# Training: 	Fold 2 - Loss: 0.3725, Accuracy: 0.8457, Precision: 0.8664, Recall: 0.9107, F1 Score: 0.8775, AUC Score: 0.9225
# Training: 	Fold 3 - Loss: 0.3748, Accuracy: 0.8457, Precision: 0.8806, Recall: 0.8922, F1 Score: 0.8780, AUC Score: 0.9299
#
# Validation: 	Fold 5 - Loss: 0.2832, Accuracy: 0.8776, Precision: 0.8260, Recall: 0.9574, F1 Score: 0.8829, AUC Score: 0.9520
#
# Epoch 116/150
# Training: 	Fold 1 - Loss: 0.3886, Accuracy: 0.7988, Precision: 0.8028, Recall: 0.8481, F1 Score: 0.8224, AUC Score: 0.9293
# Training: 	Fold 3 - Loss: 0.3833, Accuracy: 0.8340, Precision: 0.8483, Recall: 0.8830, F1 Score: 0.8609, AUC Score: 0.9058
#
# Validation: 	Fold 5 - Loss: 0.3664, Accuracy: 0.8281, Precision: 0.7689, Recall: 0.9510, F1 Score: 0.8418, AUC Score: 0.9358
#
# Epoch 117/150
# Training: 	Fold 1 - Loss: 0.3954, Accuracy: 0.8379, Precision: 0.8568, Recall: 0.8804, F1 Score: 0.8644, AUC Score: 0.9048
#
# Validation: 	Fold 5 - Loss: 0.6664, Accuracy: 0.6172, Precision: 0.9500, Recall: 0.3503, F1 Score: 0.5074, AUC Score: 0.8065
#
# Epoch 118/150
# Training: 	Fold 1 - Loss: 0.4365, Accuracy: 0.7734, Precision: 0.8035, Recall: 0.8102, F1 Score: 0.8001, AUC Score: 0.9004
# Training: 	Fold 2 - Loss: 0.3391, Accuracy: 0.8730, Precision: 0.8965, Recall: 0.8971, F1 Score: 0.8934, AUC Score: 0.9281
#
# Validation: 	Fold 5 - Loss: 0.2052, Accuracy: 0.9167, Precision: 0.8692, Recall: 0.9844, F1 Score: 0.9204, AUC Score: 0.9776
#
# Epoch 119/150
# Training: 	Fold 1 - Loss: 0.3777, Accuracy: 0.8262, Precision: 0.8157, Recall: 0.9330, F1 Score: 0.8645, AUC Score: 0.9273
# Training: 	Fold 3 - Loss: 0.3039, Accuracy: 0.8770, Precision: 0.8701, Recall: 0.9340, F1 Score: 0.8987, AUC Score: 0.9453
#
# Validation: 	Fold 5 - Loss: 0.2397, Accuracy: 0.9010, Precision: 0.8567, Recall: 0.9513, F1 Score: 0.8993, AUC Score: 0.9704
#
# Epoch 120/150
# Training: 	Fold 1 - Loss: 0.3351, Accuracy: 0.8398, Precision: 0.8777, Recall: 0.8809, F1 Score: 0.8712, AUC Score: 0.9327
# Training: 	Fold 2 - Loss: 0.2937, Accuracy: 0.8711, Precision: 0.8676, Recall: 0.9416, F1 Score: 0.8971, AUC Score: 0.9564
#
# Validation: 	Fold 5 - Loss: 0.2400, Accuracy: 0.9193, Precision: 0.9124, Recall: 0.9365, F1 Score: 0.9216, AUC Score: 0.9733
#
# Epoch 121/150
# Training: 	Fold 1 - Loss: 0.3881, Accuracy: 0.8418, Precision: 0.8393, Recall: 0.9124, F1 Score: 0.8693, AUC Score: 0.8954
# Training: 	Fold 3 - Loss: 0.3107, Accuracy: 0.8711, Precision: 0.8782, Recall: 0.9205, F1 Score: 0.8948, AUC Score: 0.9396
# Training: 	Fold 4 - Loss: 0.2998, Accuracy: 0.8809, Precision: 0.8884, Recall: 0.9187, F1 Score: 0.8986, AUC Score: 0.9376
#
# Validation: 	Fold 5 - Loss: 0.1942, Accuracy: 0.9193, Precision: 0.8853, Recall: 0.9439, F1 Score: 0.9129, AUC Score: 0.9818
#
# Epoch 122/150
# Training: 	Fold 1 - Loss: 0.3477, Accuracy: 0.8691, Precision: 0.8864, Recall: 0.9030, F1 Score: 0.8911, AUC Score: 0.9254
#
# Validation: 	Fold 5 - Loss: 0.2363, Accuracy: 0.9062, Precision: 0.8627, Recall: 0.9741, F1 Score: 0.9086, AUC Score: 0.9702
#
# Epoch 123/150
# Training: 	Fold 1 - Loss: 0.3306, Accuracy: 0.8789, Precision: 0.8838, Recall: 0.9399, F1 Score: 0.9044, AUC Score: 0.9533
#
# Validation: 	Fold 5 - Loss: 0.3422, Accuracy: 0.8411, Precision: 0.7964, Recall: 0.9127, F1 Score: 0.8443, AUC Score: 0.9290
#
# Epoch 124/150
# Training: 	Fold 1 - Loss: 0.3611, Accuracy: 0.8379, Precision: 0.8601, Recall: 0.8686, F1 Score: 0.8621, AUC Score: 0.9145
# Training: 	Fold 2 - Loss: 0.3053, Accuracy: 0.8730, Precision: 0.8788, Recall: 0.9182, F1 Score: 0.8945, AUC Score: 0.9347
# Training: 	Fold 3 - Loss: 0.2574, Accuracy: 0.8750, Precision: 0.9060, Recall: 0.9112, F1 Score: 0.9010, AUC Score: 0.9654
#
# Validation: 	Fold 5 - Loss: 0.1881, Accuracy: 0.9323, Precision: 0.8936, Recall: 0.9833, F1 Score: 0.9357, AUC Score: 0.9798
# Model with best precision during Validation saved at epoch 124 with F1 Score of 0.9357
#
# Epoch 125/150
# Training: 	Fold 1 - Loss: 0.3468, Accuracy: 0.8730, Precision: 0.8752, Recall: 0.9180, F1 Score: 0.8942, AUC Score: 0.9205
#
# Validation: 	Fold 5 - Loss: 0.2439, Accuracy: 0.8854, Precision: 0.8292, Recall: 0.9844, F1 Score: 0.8941, AUC Score: 0.9793
#
# Epoch 126/150
# Training: 	Fold 1 - Loss: 0.3144, Accuracy: 0.8828, Precision: 0.8754, Recall: 0.9362, F1 Score: 0.9016, AUC Score: 0.9418
#
# Validation: 	Fold 5 - Loss: 0.2488, Accuracy: 0.8828, Precision: 0.8518, Recall: 0.9428, F1 Score: 0.8890, AUC Score: 0.9696
#
# Epoch 127/150
# Training: 	Fold 1 - Loss: 0.2931, Accuracy: 0.8809, Precision: 0.9017, Recall: 0.9263, F1 Score: 0.9045, AUC Score: 0.9525
#
# Validation: 	Fold 5 - Loss: 0.2605, Accuracy: 0.9062, Precision: 0.8591, Recall: 0.9815, F1 Score: 0.9074, AUC Score: 0.9611
#
# Epoch 128/150
# Training: 	Fold 1 - Loss: 0.4239, Accuracy: 0.8047, Precision: 0.7928, Recall: 0.8783, F1 Score: 0.8300, AUC Score: 0.9263
# Training: 	Fold 2 - Loss: 0.3589, Accuracy: 0.8477, Precision: 0.8934, Recall: 0.8798, F1 Score: 0.8786, AUC Score: 0.9402
#
# Validation: 	Fold 5 - Loss: 0.3124, Accuracy: 0.8828, Precision: 0.8605, Recall: 0.9262, F1 Score: 0.8878, AUC Score: 0.9523
#
# Epoch 129/150
# Training: 	Fold 1 - Loss: 0.4593, Accuracy: 0.7793, Precision: 0.7718, Recall: 0.8605, F1 Score: 0.8080, AUC Score: 0.9023
# Training: 	Fold 2 - Loss: 0.3532, Accuracy: 0.8340, Precision: 0.8704, Recall: 0.8853, F1 Score: 0.8695, AUC Score: 0.9290
# Training: 	Fold 3 - Loss: 0.3543, Accuracy: 0.8691, Precision: 0.8629, Recall: 0.9288, F1 Score: 0.8920, AUC Score: 0.9245
#
# Validation: 	Fold 5 - Loss: 0.2300, Accuracy: 0.9167, Precision: 0.8801, Recall: 0.9677, F1 Score: 0.9194, AUC Score: 0.9713
#
# Epoch 130/150
# Training: 	Fold 1 - Loss: 0.5379, Accuracy: 0.7480, Precision: 0.7599, Recall: 0.8119, F1 Score: 0.7814, AUC Score: 0.8631
# Training: 	Fold 2 - Loss: 0.3734, Accuracy: 0.8477, Precision: 0.8594, Recall: 0.9017, F1 Score: 0.8769, AUC Score: 0.9051
# Training: 	Fold 3 - Loss: 0.3250, Accuracy: 0.8887, Precision: 0.8850, Recall: 0.9378, F1 Score: 0.9081, AUC Score: 0.9410
#
# Validation: 	Fold 5 - Loss: 0.2246, Accuracy: 0.9010, Precision: 0.8640, Recall: 0.9510, F1 Score: 0.9002, AUC Score: 0.9756
#
# Epoch 131/150
# Training: 	Fold 1 - Loss: 0.4291, Accuracy: 0.8008, Precision: 0.7991, Recall: 0.8589, F1 Score: 0.8254, AUC Score: 0.9152
# Training: 	Fold 2 - Loss: 0.4159, Accuracy: 0.8125, Precision: 0.8626, Recall: 0.8499, F1 Score: 0.8478, AUC Score: 0.8940
# Training: 	Fold 3 - Loss: 0.3891, Accuracy: 0.8145, Precision: 0.8436, Recall: 0.8728, F1 Score: 0.8492, AUC Score: 0.9255
#
# Validation: 	Fold 5 - Loss: 0.5634, Accuracy: 0.7865, Precision: 0.7730, Recall: 0.8466, F1 Score: 0.8021, AUC Score: 0.8201
#
# Epoch 132/150
# Training: 	Fold 1 - Loss: 0.4487, Accuracy: 0.7754, Precision: 0.8019, Recall: 0.8429, F1 Score: 0.8125, AUC Score: 0.8774
# Training: 	Fold 2 - Loss: 0.4053, Accuracy: 0.7988, Precision: 0.8298, Recall: 0.8651, F1 Score: 0.8377, AUC Score: 0.9039
# Training: 	Fold 4 - Loss: 0.3556, Accuracy: 0.8561, Precision: 0.8548, Recall: 0.9185, F1 Score: 0.8782, AUC Score: 0.9270
#
# Validation: 	Fold 5 - Loss: 0.3478, Accuracy: 0.8776, Precision: 0.8249, Recall: 0.9152, F1 Score: 0.8666, AUC Score: 0.9241
#
# Epoch 133/150
# Training: 	Fold 1 - Loss: 0.4061, Accuracy: 0.8320, Precision: 0.8534, Recall: 0.8796, F1 Score: 0.8609, AUC Score: 0.8978
# Training: 	Fold 2 - Loss: 0.3335, Accuracy: 0.8555, Precision: 0.8688, Recall: 0.8999, F1 Score: 0.8812, AUC Score: 0.9303
# Training: 	Fold 3 - Loss: 0.3121, Accuracy: 0.8750, Precision: 0.8767, Recall: 0.9250, F1 Score: 0.8969, AUC Score: 0.9405
# Training: 	Fold 4 - Loss: 0.2798, Accuracy: 0.8815, Precision: 0.9089, Recall: 0.9106, F1 Score: 0.9027, AUC Score: 0.9592
#
# Validation: 	Fold 5 - Loss: 0.1415, Accuracy: 0.9453, Precision: 0.9062, Recall: 0.9833, F1 Score: 0.9413, AUC Score: 0.9909
# Model with best precision during Validation saved at epoch 133 with F1 Score of 0.9413
#
# Epoch 134/150
# Training: 	Fold 1 - Loss: 0.2903, Accuracy: 0.8691, Precision: 0.8636, Recall: 0.9472, F1 Score: 0.8978, AUC Score: 0.9498
#
# Validation: 	Fold 5 - Loss: 0.3513, Accuracy: 0.8177, Precision: 0.8077, Recall: 0.8491, F1 Score: 0.8226, AUC Score: 0.9210
#
# Epoch 135/150
# Training: 	Fold 1 - Loss: 0.3916, Accuracy: 0.8398, Precision: 0.8342, Recall: 0.9200, F1 Score: 0.8699, AUC Score: 0.9012
# Training: 	Fold 2 - Loss: 0.3846, Accuracy: 0.8535, Precision: 0.8612, Recall: 0.9100, F1 Score: 0.8810, AUC Score: 0.9084
#
# Validation: 	Fold 5 - Loss: 0.1887, Accuracy: 0.9375, Precision: 0.8988, Recall: 1.0000, F1 Score: 0.9429, AUC Score: 0.9861
# Model with best precision during Validation saved at epoch 135 with F1 Score of 0.9429
#
# Epoch 136/150
# Training: 	Fold 1 - Loss: 0.4433, Accuracy: 0.8125, Precision: 0.8058, Recall: 0.8759, F1 Score: 0.8370, AUC Score: 0.9361
# Training: 	Fold 2 - Loss: 0.3550, Accuracy: 0.8594, Precision: 0.8754, Recall: 0.8997, F1 Score: 0.8836, AUC Score: 0.9217
# Training: 	Fold 3 - Loss: 0.3376, Accuracy: 0.8652, Precision: 0.8641, Recall: 0.9380, F1 Score: 0.8929, AUC Score: 0.9387
# Training: 	Fold 4 - Loss: 0.3089, Accuracy: 0.8809, Precision: 0.9080, Recall: 0.8990, F1 Score: 0.8999, AUC Score: 0.9366
#
# Validation: 	Fold 5 - Loss: 0.2301, Accuracy: 0.9036, Precision: 0.8868, Recall: 0.9265, F1 Score: 0.9028, AUC Score: 0.9665
#
# Epoch 137/150
# Training: 	Fold 1 - Loss: 0.3418, Accuracy: 0.8555, Precision: 0.8560, Recall: 0.9122, F1 Score: 0.8779, AUC Score: 0.9216
#
# Validation: 	Fold 5 - Loss: 0.2310, Accuracy: 0.9089, Precision: 0.8678, Recall: 0.9616, F1 Score: 0.9111, AUC Score: 0.9739
#
# Epoch 138/150
# Training: 	Fold 1 - Loss: 0.3682, Accuracy: 0.8320, Precision: 0.8464, Recall: 0.8820, F1 Score: 0.8583, AUC Score: 0.9056
# Training: 	Fold 2 - Loss: 0.3045, Accuracy: 0.8457, Precision: 0.8623, Recall: 0.9105, F1 Score: 0.8788, AUC Score: 0.9483
# Training: 	Fold 4 - Loss: 0.3726, Accuracy: 0.8548, Precision: 0.8706, Recall: 0.9033, F1 Score: 0.8823, AUC Score: 0.9532
#
# Validation: 	Fold 5 - Loss: 0.1457, Accuracy: 0.9479, Precision: 0.9606, Recall: 0.9294, F1 Score: 0.9439, AUC Score: 0.9920
# Model with best precision during Validation saved at epoch 138 with F1 Score of 0.9439
#
# Epoch 139/150
# Training: 	Fold 1 - Loss: 0.3175, Accuracy: 0.8926, Precision: 0.9112, Recall: 0.9145, F1 Score: 0.9111, AUC Score: 0.9463
#
# Validation: 	Fold 5 - Loss: 0.4781, Accuracy: 0.7344, Precision: 0.9583, Recall: 0.5334, F1 Score: 0.6810, AUC Score: 0.9420
#
# Epoch 140/150
# Training: 	Fold 1 - Loss: 0.3721, Accuracy: 0.8301, Precision: 0.8633, Recall: 0.8813, F1 Score: 0.8637, AUC Score: 0.9226
# Training: 	Fold 2 - Loss: 0.3198, Accuracy: 0.8809, Precision: 0.8866, Recall: 0.9302, F1 Score: 0.9021, AUC Score: 0.9413
#
# Validation: 	Fold 5 - Loss: 0.1536, Accuracy: 0.9375, Precision: 0.9059, Recall: 0.9741, F1 Score: 0.9365, AUC Score: 0.9889
#
# Epoch 141/150
# Training: 	Fold 1 - Loss: 0.3196, Accuracy: 0.8535, Precision: 0.8869, Recall: 0.8947, F1 Score: 0.8819, AUC Score: 0.9451
# Training: 	Fold 2 - Loss: 0.2912, Accuracy: 0.8672, Precision: 0.8836, Recall: 0.9167, F1 Score: 0.8939, AUC Score: 0.9519
#
# Validation: 	Fold 5 - Loss: 0.2439, Accuracy: 0.8958, Precision: 0.9125, Recall: 0.8878, F1 Score: 0.8989, AUC Score: 0.9787
#
# Epoch 142/150
# Training: 	Fold 1 - Loss: 0.2862, Accuracy: 0.9004, Precision: 0.9063, Recall: 0.9289, F1 Score: 0.9141, AUC Score: 0.9509
# Training: 	Fold 3 - Loss: 0.2314, Accuracy: 0.9121, Precision: 0.9162, Recall: 0.9441, F1 Score: 0.9277, AUC Score: 0.9661
#
# Validation: 	Fold 5 - Loss: 0.1564, Accuracy: 0.9349, Precision: 0.9205, Recall: 0.9584, F1 Score: 0.9360, AUC Score: 0.9855
#
# Epoch 143/150
# Training: 	Fold 1 - Loss: 0.3190, Accuracy: 0.8535, Precision: 0.8920, Recall: 0.8905, F1 Score: 0.8821, AUC Score: 0.9460
# Training: 	Fold 3 - Loss: 0.3089, Accuracy: 0.8867, Precision: 0.8836, Recall: 0.9395, F1 Score: 0.9060, AUC Score: 0.9413
#
# Validation: 	Fold 5 - Loss: 0.1301, Accuracy: 0.9688, Precision: 0.9613, Recall: 0.9667, F1 Score: 0.9633, AUC Score: 0.9940
# Model with best precision during Validation saved at epoch 143 with F1 Score of 0.9633
#
# Epoch 144/150
# Training: 	Fold 1 - Loss: 0.3222, Accuracy: 0.8613, Precision: 0.8917, Recall: 0.9010, F1 Score: 0.8889, AUC Score: 0.9465
# Training: 	Fold 2 - Loss: 0.2999, Accuracy: 0.8789, Precision: 0.8841, Recall: 0.9284, F1 Score: 0.9005, AUC Score: 0.9415
# Training: 	Fold 3 - Loss: 0.2645, Accuracy: 0.8926, Precision: 0.8849, Recall: 0.9433, F1 Score: 0.9081, AUC Score: 0.9538
#
# Validation: 	Fold 5 - Loss: 0.1660, Accuracy: 0.9271, Precision: 0.8927, Recall: 0.9741, F1 Score: 0.9280, AUC Score: 0.9906
#
# Epoch 145/150
# Training: 	Fold 1 - Loss: 0.2339, Accuracy: 0.9180, Precision: 0.9375, Recall: 0.9288, F1 Score: 0.9302, AUC Score: 0.9659
#
# Validation: 	Fold 5 - Loss: 0.1235, Accuracy: 0.9688, Precision: 0.9702, Recall: 0.9667, F1 Score: 0.9667, AUC Score: 0.9929
# Model with best precision during Validation saved at epoch 145 with F1 Score of 0.9667
#
# Epoch 146/150
# Training: 	Fold 1 - Loss: 0.3227, Accuracy: 0.8906, Precision: 0.8935, Recall: 0.9185, F1 Score: 0.9032, AUC Score: 0.9269
#
# Validation: 	Fold 5 - Loss: 0.5451, Accuracy: 0.7708, Precision: 0.7336, Recall: 0.9236, F1 Score: 0.8040, AUC Score: 0.8301
#
# Epoch 147/150
# Training: 	Fold 1 - Loss: 0.4673, Accuracy: 0.8164, Precision: 0.8018, Recall: 0.8299, F1 Score: 0.8119, AUC Score: 0.8870
# Training: 	Fold 2 - Loss: 0.3941, Accuracy: 0.8301, Precision: 0.8163, Recall: 0.8348, F1 Score: 0.8225, AUC Score: 0.9233
# Training: 	Fold 3 - Loss: 0.3144, Accuracy: 0.8848, Precision: 0.9254, Recall: 0.9057, F1 Score: 0.9079, AUC Score: 0.9536
# Training: 	Fold 4 - Loss: 0.2725, Accuracy: 0.8965, Precision: 0.8998, Recall: 0.9336, F1 Score: 0.9151, AUC Score: 0.9541
#
# Validation: 	Fold 5 - Loss: 0.1557, Accuracy: 0.9427, Precision: 0.9449, Recall: 0.9492, F1 Score: 0.9448, AUC Score: 0.9869
#
# Epoch 148/150
# Training: 	Fold 1 - Loss: 0.2947, Accuracy: 0.8691, Precision: 0.8994, Recall: 0.9044, F1 Score: 0.8940, AUC Score: 0.9494
# Training: 	Fold 2 - Loss: 0.3260, Accuracy: 0.8711, Precision: 0.9080, Recall: 0.9095, F1 Score: 0.8994, AUC Score: 0.9425
#
# Validation: 	Fold 5 - Loss: 0.2142, Accuracy: 0.9167, Precision: 0.9003, Recall: 0.9450, F1 Score: 0.9215, AUC Score: 0.9704
#
# Epoch 149/150
# Training: 	Fold 1 - Loss: 0.3207, Accuracy: 0.8574, Precision: 0.9067, Recall: 0.8760, F1 Score: 0.8833, AUC Score: 0.9388
# Training: 	Fold 3 - Loss: 0.2764, Accuracy: 0.8926, Precision: 0.9057, Recall: 0.9195, F1 Score: 0.9101, AUC Score: 0.9559
#
# Validation: 	Fold 5 - Loss: 0.1373, Accuracy: 0.9609, Precision: 0.9470, Recall: 0.9833, F1 Score: 0.9642, AUC Score: 0.9929
#
# Epoch 150/150
# Training: 	Fold 1 - Loss: 0.2932, Accuracy: 0.9082, Precision: 0.8981, Recall: 0.9547, F1 Score: 0.9238, AUC Score: 0.9440
#
# Validation: 	Fold 5 - Loss: 0.2648, Accuracy: 0.8906, Precision: 0.8848, Recall: 0.9108, F1 Score: 0.8958, AUC Score: 0.9574

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
mbnetv2.load_state_dict(torch.load(f'{weights_path}\\mbnetv2_best_f1score.pth', weights_only=True))
test_loss, test_performance_metrics = eval(test_loader, mbnetv2, loss_fn, 'Testing', CumulativeMetrics())
test_accuracy, test_precision, test_recall, test_f1, test_auc = test_performance_metrics.values()
print(f"Testing: \tLoss: {test_loss:.4f}, Accuracy: {test_accuracy:.4f}, Precision: {test_precision:.4f}, Recall: {test_recall:.4f}, F1 Score: {test_f1:.4f}, AUC Score: {test_auc:.4f}")
# Out:
# Testing: 	Loss: 0.2133, Accuracy: 0.9148, Precision: 0.9735, Recall: 0.8968, F1 Score: 0.9334, AUC Score: 0.9703

# %%
def print_model_size(title, mdl):
    torch.save(mdl.state_dict(), "tmp.pt")
    print(title, "%.2f MB" %(os.path.getsize("tmp.pt")/1e6))
    os.remove('tmp.pt')

print_model_size("MobileNetV2 w/ Pre-trained Weights (ImageNet1K) Trained on CP-AnemiC Dataset:", mbnetv2)
# Out:
# MobileNetV2 w/ Pre-trained Weights (ImageNet1K) Trained on CP-AnemiC Dataset: 9.12 MB

# %%
train_metrics_df = pd.DataFrame(train_metrics_df)
display(train_metrics_df.sort_values(by='Accuracy', ascending=False)[:25])
# Out:
#          Loss  Accuracy  Precision    Recall  F1 Score       AUC
# 322  0.233860  0.917969   0.937505  0.928810  0.930204  0.965891
# 316  0.231390  0.912109   0.916233  0.944107  0.927733  0.966141
# 332  0.293198  0.908203   0.898127  0.954742  0.923838  0.943985
# 315  0.286205  0.900391   0.906296  0.928948  0.914079  0.950888
# 327  0.272546  0.896484   0.899841  0.933590  0.915117  0.954108
# 331  0.276448  0.892578   0.905725  0.919539  0.910121  0.955901
# 310  0.317534  0.892578   0.911232  0.914484  0.911120  0.946286
# 321  0.264468  0.892578   0.884936  0.943301  0.908081  0.953761
# 323  0.322700  0.890625   0.893490  0.918463  0.903192  0.926895
# 288  0.324976  0.888672   0.884969  0.937805  0.908102  0.940970
# 318  0.308861  0.886719   0.883636  0.939491  0.906041  0.941255
# 219  0.300824  0.884766   0.882338  0.936087  0.907214  0.943938
# 326  0.314401  0.884766   0.925436  0.905743  0.907852  0.953636
# 279  0.314356  0.882812   0.875419  0.936159  0.901589  0.941755
# 298  0.279800  0.881510   0.908889  0.910642  0.902722  0.959173
# 280  0.293122  0.880859   0.901672  0.926283  0.904507  0.952530
# 305  0.308935  0.880859   0.907961  0.899019  0.899891  0.936610
# 272  0.299791  0.880859   0.888432  0.918665  0.898553  0.937645
# 312  0.319849  0.880859   0.886628  0.930154  0.902060  0.941347
# 274  0.330645  0.878906   0.883821  0.939860  0.904393  0.953315
# 246  0.299900  0.878906   0.865496  0.946386  0.901333  0.947205
# 320  0.299931  0.878906   0.884129  0.928379  0.900549  0.941527
# 267  0.303863  0.876953   0.870107  0.934037  0.898652  0.945340
# 256  0.306285  0.876953   0.865768  0.937316  0.898813  0.934546
# 297  0.312149  0.875000   0.876737  0.924999  0.896923  0.940542

# %%
val_metrics_df = pd.DataFrame(val_metrics_df)
display(val_metrics_df.sort_values(by='Accuracy', ascending=False)[:25])
# Out:
#         Loss  Accuracy  Precision    Recall  F1 Score       AUC
# 21  0.123531  0.968750   0.970238  0.966667  0.966728  0.992896
# 20  0.130086  0.968750   0.961310  0.966667  0.963268  0.994032
# 19  0.145700  0.947917   0.960606  0.929356  0.943939  0.992043
# 17  0.141495  0.945312   0.906250  0.983333  0.941261  0.990907
# 18  0.188731  0.937500   0.898810  1.000000  0.942918  0.986076
# 16  0.188116  0.932292   0.893582  0.983333  0.935722  0.979824
# 15  0.164386  0.924479   0.898012  0.974074  0.933915  0.990622
# 14  0.264815  0.911458   0.856737  0.990741  0.915292  0.968173
# 12  0.256503  0.901042   0.895433  0.903430  0.896627  0.966468
# 13  0.270074  0.898438   0.837946  0.983333  0.899158  0.957090
# 11  0.325318  0.882812   0.841618  0.905892  0.870536  0.933220
# 10  0.316199  0.864583   0.828804  0.902694  0.861028  0.936914
# 9   0.342463  0.851562   0.810953  0.919055  0.859190  0.932083
# 8   0.314824  0.841146   0.807425  0.891004  0.841081  0.943450
# 7   0.378752  0.835938   0.773841  0.921212  0.839689  0.921569
# 6   0.385688  0.817708   0.761749  0.951347  0.833859  0.922989
# 4   0.476599  0.770833   0.728605  0.933870  0.805956  0.857914
# 5   0.507791  0.763021   0.714156  0.965856  0.806994  0.856493
# 3   0.508431  0.734375   0.716665  0.874611  0.770945  0.800227
# 2   0.635958  0.697917   0.676947  0.894171  0.753127  0.699631
# 1   0.659125  0.625000   0.614919  0.984375  0.735088  0.605570
# 0   0.697231  0.580729   0.580729  1.000000  0.716295  0.622336

# %%
plt.figure(figsize=(10,7))
train_loss_df = train_metrics_df["Loss"]
plt.plot(range(len(train_loss_df)), train_loss_df)
plt.title("Training Loss per Fold during 5-fold Cross-Validation on CP-AnemiC Dataset")
plt.xlabel("Best Folds")
plt.ylabel("Cross-Entropy Loss")
plt.show()

plt.figure(figsize=(10,7))
train_acc_df = train_metrics_df["Accuracy"]
plt.plot(range(len(train_acc_df)), train_acc_df)
plt.title("Training Accuracy per Fold during 5-fold Cross-Validation on CP-AnemiC Dataset")
plt.xlabel("Best Folds")
plt.ylabel("Accuracy")
plt.show()

# %%
plt.figure(figsize=(10,7))
val_loss_df = val_metrics_df["Loss"]
plt.plot(range(len(val_loss_df)), val_loss_df)
plt.title("Validation Loss per Fold during 5-fold Cross-Validation on CP-AnemiC Dataset")
plt.xlabel("Best Folds")
plt.ylabel("Cross-Entropy Loss")
plt.show()

plt.figure(figsize=(10,7))
val_acc_df = val_metrics_df["Loss"]
plt.plot(range(len(val_acc_df)), val_acc_df)
plt.title("Validation Accuracy per Fold during 5-fold Cross-Validation on CP-AnemiC Dataset")
plt.xlabel("Best Folds")
plt.ylabel("Accuracy")
plt.show()
