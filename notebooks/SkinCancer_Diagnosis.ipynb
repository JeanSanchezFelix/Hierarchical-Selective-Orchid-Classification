# %% [markdown]
# # Transfer Learning

# %% [markdown]
# ### Import Libraries

# %%
import pathlib
import os
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
# import keras_tuner as kt
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import StratifiedKFold, train_test_split

# %% [markdown]
# ## Train with Skin Cancer Dataset

# %% [markdown]
# ### Hyperparameters

# %%
data_root = pathlib.Path("../data/Augmented_Images")    # points to the folder containing the images that will be used for training

# hyperparameters
img_height = 224        # input image height
img_width = 224         # input image width
batch_size = 32         # size of the batch that will be fed to model

# folds = the amount of folds that will be created for cross-validation
# fine_tune_epochs = number of epochs after which we start fine-tuning
# fine_tune_at = layer number where we start unfreezing layers

# configurations that will be used in training
configs = [
    {"learning_rate": 0.001, "optimizer": "adam", "epochs": 50, "save_metrics": True, "folds": 5, "fine_tune": False, "fine_tune_epochs": 25, "fine_tune_at": 150},
    {"learning_rate": 0.001, "optimizer": "adam", "epochs": 50, "save_metrics": True, "folds": 3, "fine_tune": False, "fine_tune_epochs": 25, "fine_tune_at": 150},
    {"learning_rate": 0.001, "optimizer": "adam", "epochs": 50, "save_metrics": True, "folds": 5, "fine_tune": True, "fine_tune_epochs": 25, "fine_tune_at": 152},
    {"learning_rate": 0.001, "optimizer": "adam", "epochs": 50, "save_metrics": True, "folds": 3, "fine_tune": True, "fine_tune_epochs": 25, "fine_tune_at": 152},
]

# Define the base path for saving models
save_dir = "../saved_models"
os.makedirs(save_dir, exist_ok=True)

# %% [markdown]
# ## Training

# %% [markdown]
# ### Setup

# %%
# Load dataset without splitting
dataset = tf.keras.utils.image_dataset_from_directory(
    data_root,                                  # loads images from the data_root directory
    image_size=(img_height, img_width),         # resizes all images to (224, 224) pixels
    batch_size=batch_size,                      # set the batch size
    shuffle=True                                # shufle data when loaded
)

class_names = np.array(dataset.class_names)     # get the class names for the data
num_classes = len(class_names)                  # get the number of classes in the dataset

# convert the dataset to a list of (image, label) pairs. This makes it easier to perform cross-validation
image_paths, labels = [], []
for image_batch, label_batch in dataset:
    image_paths.extend(image_batch.numpy())
    labels.extend(label_batch.numpy())

image_paths = np.array(image_paths)             # convert to numpy array to facilitate training
labels = np.array(labels)                       # convert to numpy array to facilitate training

# Split the dataset into training/validation and test sets
train_val_images, test_images, train_val_labels, test_labels = train_test_split(
    image_paths, labels, test_size=0.10, random_state=42, stratify=labels
)

def callbacks_setup(checkpoint_filepath):
    # EarlyStopping callback configuration
    early_stopping = EarlyStopping(
        monitor='val_loss',        # monitor validation loss
        patience=3,                # number of epochs with no improvement to stop training
        mode = 'min',              # want to minimize what it being monitored 
        restore_best_weights=False # don't restore in EarlyStopping, handled by ModelCheckpoint
    )

    model_checkpoint = ModelCheckpoint(
        filepath=checkpoint_filepath,   # path to save weights
        save_weights_only=True,         # only save weights instead of full model
        monitor='val_precision',        # monitor validation loss
        mode='max',                     # want to maximize what is being monitored
        save_best_only=True             # save the best weights
    )            

    return early_stopping, model_checkpoint
# Out:
# Found 3192 files belonging to 2 classes.

# %% [markdown]
# ### Metrics

# %%
from sklearn.metrics import precision_score, classification_report, roc_auc_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay

# plot and save confusion matrix
def save_confusion_matrix(true_labels, predicted_labels, class_names, save_path):
    cm = confusion_matrix(true_labels, predicted_labels)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues)
    plt.title("Confusion Matrix")
    plt.savefig(save_path)
    plt.close()

# plot and save loss curves
def save_loss_curve(history, save_path):
    plt.figure(figsize=(10, 6))
    plt.plot(history['loss'], label='Training Loss', color='blue')
    plt.plot(history['val_loss'], label='Validation Loss', color='orange')
    plt.title("Training and Validation Loss Over Epochs")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.savefig(save_path)
    plt.close()

# compute and plot evaluation metrics (accuracy, sensitivity, specificity, F1 score)
def save_evaluation_metrics(true_labels, predicted_labels, history, cm, save_path):
    accuracy = history['val_accuracy'][-1]
    sensitivity = recall_score(true_labels, predicted_labels, average='macro')
    specificity = np.mean(np.diag(cm) / (np.diag(cm) + np.sum(cm, axis=0) - np.diag(cm)))
    f1 = f1_score(true_labels, predicted_labels, average='macro')

    metrics = {
        "Accuracy": accuracy,
        "Sensitivity (Recall)": sensitivity,
        "Specificity": specificity,
        "F1-Score": f1
    }

    plt.figure(figsize=(10, 6))
    plt.bar(metrics.keys(), metrics.values(), color=['darkturquoise', 'sandybrown', 'hotpink', 'limegreen'])
    plt.title("Model Evaluation Metrics")
    plt.ylim([0, 1])
    plt.yticks(np.arange(0, 1.1, 0.1))
    plt.ylabel("Score")
    plt.savefig(save_path)
    plt.close()
    return metrics

# save classification report
def save_classification_report(true_labels, predicted_labels, class_names, save_path):
    class_report = classification_report(true_labels, predicted_labels, target_names=class_names, digits=4)
    with open(save_path, "w") as f:
        f.write(class_report)

# Function to calculate metrics
def calculate_metrics(true_labels, predictions):
    accuracy = np.mean(np.argmax(predictions, axis=1) == true_labels)
    precision = precision_score(true_labels, np.argmax(predictions, axis=1), average='macro')
    recall = recall_score(true_labels, np.argmax(predictions, axis=1), average='macro')
    f1 = f1_score(true_labels, np.argmax(predictions, axis=1), average='macro')
    auc = roc_auc_score(tf.keras.utils.to_categorical(true_labels), predictions, multi_class='ovr')
    return accuracy, precision, recall, f1, auc

# Function to save metrics, loss curve, and confusion matrix for the best model
def save_best_model_visuals(history, model, val_ds, class_names, weights_path, fold):
    # generate predictions for the validation set
    val_predictions = model.predict(val_ds)
    val_predicted_ids = np.argmax(val_predictions, axis=-1)
    true_labels = np.concatenate([y for x, y in val_ds], axis=0)

    # confusion Matrix
    confusion_matrix_path = os.path.join(weights_path, f"confusion_matrix_fold_{fold}.png")
    save_confusion_matrix(true_labels, val_predicted_ids, class_names, confusion_matrix_path)

    # loss curve
    loss_curve_path = os.path.join(weights_path, f"loss_curve_fold_{fold}.png")
    save_loss_curve(history.history, loss_curve_path)

    # evaluation Metrics (Accuracy, Sensitivity, Specificity, F1 Score)
    cm = confusion_matrix(true_labels, val_predicted_ids)
    metrics_bar_chart_path = os.path.join(weights_path, f"evaluation_metrics_fold_{fold}.png")
    save_evaluation_metrics(true_labels, val_predicted_ids, history.history, cm, metrics_bar_chart_path)

    # save classification report as a text file
    classification_report_path = os.path.join(weights_path, f"classification_report_fold_{fold}.txt")
    save_classification_report(true_labels, val_predicted_ids, class_names, classification_report_path)

# %% [markdown]
# ### Automated Hyperparameter Tuning

# %%
# # Split data into training/validation set for hyperparameter tuning
# train_images_tuning, val_images_tuning, train_labels_tuning, val_labels_tuning = train_test_split(
#     image_paths, labels, test_size=0.1, random_state=42, stratify=labels
# )

# # Define the hypermodel for hyperparameter tuning
# def build_model(hp):
#     base_model = tf.keras.applications.MobileNetV2(
#         input_shape=(img_height, img_width, 3),
#         include_top=False,
#         weights='imagenet'
#     )
#     base_model.trainable = False  # Freeze layers initially
    
#     model = Sequential([
#         base_model,
#         layers.GlobalAveragePooling2D(),
#         layers.Dense(num_classes)
#     ])

#     # Tune hyperparameters
#     learning_rate = hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log')
#     optimizer = hp.Choice('optimizer', values=['adam', 'sgd'])

#     if optimizer == 'adam':
#         opt = tf.keras.optimizers.Adam(learning_rate=learning_rate)
#     else:
#         opt = tf.keras.optimizers.SGD(learning_rate=learning_rate)

#     model.compile(
#         optimizer=opt,
#         loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#         metrics=['accuracy']
#     )
    
#     return model

# # Set up the tuner for hyperparameter tuning
# tuner = kt.RandomSearch(
#     build_model,
#     objective='val_accuracy',  # Optimize for validation accuracy
#     max_trials=10,             # Try 10 different hyperparameter combinations
#     executions_per_trial=1,    # Run each combination once
#     directory='hyperparameter_tuning',
#     project_name='best_hyperparams_tuning'
# )

# # Prepare TensorFlow datasets for training and validation
# train_ds = tf.data.Dataset.from_tensor_slices((train_images_tuning, train_labels_tuning)).batch(batch_size)
# val_ds = tf.data.Dataset.from_tensor_slices((val_images_tuning, val_labels_tuning)).batch(batch_size)

# # Perform the hyperparameter search on the validation set
# tuner.search(train_ds, validation_data=val_ds, epochs=10)

# # Get the best hyperparameters after the search
# best_hyperparams = tuner.get_best_hyperparameters(num_trials=1)[0]

# # Print the best hyperparameters
# print(f"Best Hyperparameters: {best_hyperparams.values}")

# %% [markdown]
# ### Model creation and fine tuning

# %%
# Function to create and compile the model
def create_model(num_classes, config, fine_tune=None):
    # if you are not fine tuning the model, instantiate a new model 
    if(fine_tune == False):         
        # instantiate mobilenet (contains 154 layers)
        base_model = tf.keras.applications.MobileNetV2(
            input_shape=(img_height, img_width, 3),     # set the input it will receive
            include_top=False,                          # do not include top layer to perform transfer learning
            weights='imagenet'                          # load weights from imagenet dataset
        )
        base_model.trainable = False                    # Freeze the base model
        
        # add a layer in order to perform classification on our dataset
        model = Sequential([
            base_model,                         # use base_model as the start of your model
            layers.GlobalAveragePooling2D(),    # add a final layer to perform classification
            layers.Dense(num_classes)           # set the number of possible prediction to the num of classes in dataset
        ])
        
    # select optimizer and learning rate based on configuration
    if config["optimizer"] == "adam":
        optimizer = tf.keras.optimizers.Adam(learning_rate=config["learning_rate"])
    elif config["optimizer"] == "sgd":
        optimizer = tf.keras.optimizers.SGD(learning_rate=config["learning_rate"])
    else:
        raise ValueError(f"Unsupported optimizer: {config['optimizer']}")

    # compile the model
    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
        metrics=['accuracy', tf.keras.metrics.Precision(name='precision')]
    )
    
    return model

# fine tune model by unfreezing the layers after the first fine_tune_at layers
def fine_tune_model(base_model, fine_tune_at):
    # Unfreeze the layers starting from fine_tune_at index
    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False
    for layer in base_model.layers[fine_tune_at:]:
        layer.trainable = True

# %% [markdown]
# ### Training loop

# %%
train_metrics = []      # list to save training metrics
val_metrics = []        # list to save validation metrics

for i, config in enumerate(configs):
    print(f"Training model {i + 1}/{len(configs)} with config: {config}")

    # K-fold Cross Validation
    kfold = StratifiedKFold(n_splits=config['folds'], shuffle=True, random_state=42)
    best_val_f1score = -float('inf')            # Initialize best F1 score with a very low value

    # Define the base path for saving models
    model_subdir = os.path.join(save_dir, f'model{i + 1}')
    os.makedirs(model_subdir, exist_ok=True)

    # Define the base path for saving checkpoints for model
    checkpoint_folder = os.path.join(model_subdir, 'checkpoints')
    os.makedirs(checkpoint_folder, exist_ok=True)

    # Define the base path for saving cthe model with the best f1-score
    best_f1_dir = os.path.join(model_subdir, 'best_f1score_fold')
    os.makedirs(best_f1_dir, exist_ok=True)
    
    # Training and validation loop for each fold
    fold = 1
    for train_idx, val_idx in kfold.split(train_val_images, train_val_labels):
        print(f"\nFold {fold}/{config['folds']}...")

        checkpoint_filepath = os.path.join(checkpoint_folder, f'checkpoint_fold{fold}.weights.h5')

        # Create subset datasets for training and validation
        train_images, train_labels = train_val_images[train_idx], train_val_labels[train_idx]
        val_images, val_labels = train_val_images[val_idx], train_val_labels[val_idx]

        # Convert NumPy arrays back to TensorFlow datasets
        train_ds = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
        val_ds = tf.data.Dataset.from_tensor_slices((val_images, val_labels))

        # Normalize datasets 
        normalization_layer = layers.Rescaling(1./255)
        train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
        val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))

        # prefetch data to improve performance by overlapping data preprocessing and model execution and cache the dataset in memory and batch
        AUTOTUNE = tf.data.AUTOTUNE
        train_ds = train_ds.batch(batch_size).cache().prefetch(buffer_size=AUTOTUNE)
        val_ds = val_ds.batch(batch_size).cache().prefetch(buffer_size=AUTOTUNE)

        # Step 1: Train model with frozen layers
        print(f"Training with frozen base layers for {config['epochs']} epochs...")

        # Create and compile model for each fold
        model = create_model(num_classes, config, fine_tune=False) 

        # setup callbacks 
        early_stopping, model_checkpoint = callbacks_setup(checkpoint_filepath)

        # train the model on the training set until the epochs specified
        history_frozen = model.fit(
            train_ds,                                       # dataset used for training
            validation_data=val_ds,                         # dataset used for validation
            epochs=config['epochs'],                        # epochs used for training
            callbacks=[early_stopping, model_checkpoint],   # set early stopping to avoid overfitting
            verbose=1
        )

        # load the best weights from ModelCheckpoint after training
        model.load_weights(checkpoint_filepath)

        if(config["fine_tune"] == True):
            # Step 2: Unfreeze layers and fine-tune
            print(f"Unfreezing layers starting from layer {config['fine_tune_at']} for fine-tuning...")
            fine_tune_model(model.layers[0], config['fine_tune_at'])      # fine tune model

            # re-compile the model with a lower learning rate for fine-tuning
            fine_tune_lr = config['learning_rate'] * 0.01

            model.compile(
                optimizer=tf.keras.optimizers.Adam(learning_rate=fine_tune_lr),
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy']
            )
                
            print(f"Fine-tuning for {config['fine_tune_epochs']} epochs...")

            # setup callbacks again for fine-tuning phase with a unique checkpoint
            early_stopping, model_checkpoint = callbacks_setup(checkpoint_filepath)
            
            history_fine_tune = model.fit(
                train_ds,                                       # dataset used for training
                validation_data=val_ds,                         # dataset used for validation
                epochs=config['fine_tune_epochs'],                        # epochs used for training
                callbacks=[early_stopping, model_checkpoint],   # set early stopping to avoid overfitting
                verbose=1
            )

            # load weights after fine-tuning
            model.load_weights(checkpoint_filepath)

        # evaluate on validation set after training
        val_predictions = model.predict(val_ds)
        avg_val_loss = model.evaluate(val_ds, verbose=0)[0]
        avg_val_accuracy, avg_val_precision, avg_val_recall, avg_val_f1, avg_val_auc = calculate_metrics(
            np.concatenate([y for x, y in val_ds]), val_predictions
        )

        print(f"\nValidation: \tFold {fold} - Loss: {avg_val_loss:.4f}, Accuracy: {avg_val_accuracy:.4f}, Precision: {avg_val_precision:.4f}, Recall: {avg_val_recall:.4f}, F1 Score: {avg_val_f1:.4f}, AUC Score: {avg_val_auc:.4f}")

        # save the best model based on validation F1 score
        if avg_val_f1 > best_val_f1score:
            best_val_f1score = avg_val_f1
            model.export(best_f1_dir)
            print(f"Model with best F1 score during Validation saved at Fold {fold} with F1 Score of {best_val_f1score:.4f}")

            if (config['save_metrics'] == True):
                #save confusion matrix, loss curve, evaluation metrics for the best model
                history = history_frozen
                save_best_model_visuals(history, model, val_ds, class_names, model_subdir, fold)

        fold += 1       # Move to the next fold

# save metrics after training
# np.save(os.path.join(save_dir, 'train_metrics.npy'), train_metrics)
# np.save(os.path.join(save_dir, 'val_metrics.npy'), val_metrics)
# Out:
# Training model 1/1 with config: {'learning_rate': 0.001, 'optimizer': 'adam', 'epochs': 50, 'save_metrics': True, 'fine_tune': False}
#
# Fold 1/5...
# Training with frozen base layers for 50 epochs...
# Epoch 1/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 148ms/step - accuracy: 0.6890 - loss: 0.5934 - val_accuracy: 0.8313 - val_loss: 0.4135
# Epoch 2/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.8421 - loss: 0.3719 - val_accuracy: 0.8504 - val_loss: 0.3512
# Epoch 3/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.8733 - loss: 0.3115 - val_accuracy: 0.8678 - val_loss: 0.3176
# Epoch 4/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 141ms/step - accuracy: 0.8918 - loss: 0.2747 - val_accuracy: 0.8852 - val_loss: 0.2954
# Epoch 5/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - accuracy: 0.9034 - loss: 0.2488 - val_accuracy: 0.8870 - val_loss: 0.2791
# Epoch 6/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - accuracy: 0.9107 - loss: 0.2291 - val_accuracy: 0.8887 - val_loss: 0.2665
# Epoch 7/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - accuracy: 0.9182 - loss: 0.2133 - val_accuracy: 0.8957 - val_loss: 0.2564
# Epoch 8/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.9269 - loss: 0.2002 - val_accuracy: 0.9078 - val_loss: 0.2482
# Epoch 9/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9304 - loss: 0.1891 - val_accuracy: 0.9113 - val_loss: 0.2413
# Epoch 10/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9314 - loss: 0.1795 - val_accuracy: 0.9183 - val_loss: 0.2355
# Epoch 11/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9343 - loss: 0.1711 - val_accuracy: 0.9183 - val_loss: 0.2305
# Epoch 12/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - accuracy: 0.9392 - loss: 0.1637 - val_accuracy: 0.9200 - val_loss: 0.2263
# Epoch 13/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9406 - loss: 0.1570 - val_accuracy: 0.9200 - val_loss: 0.2225
# Epoch 14/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 158ms/step - accuracy: 0.9421 - loss: 0.1510 - val_accuracy: 0.9200 - val_loss: 0.2192
# Epoch 15/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.9463 - loss: 0.1455 - val_accuracy: 0.9183 - val_loss: 0.2162
# Epoch 16/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 14s 188ms/step - accuracy: 0.9484 - loss: 0.1405 - val_accuracy: 0.9183 - val_loss: 0.2135
# Epoch 17/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 184ms/step - accuracy: 0.9512 - loss: 0.1359 - val_accuracy: 0.9183 - val_loss: 0.2110
# Epoch 18/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9521 - loss: 0.1316 - val_accuracy: 0.9165 - val_loss: 0.2087
# Epoch 19/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 182ms/step - accuracy: 0.9533 - loss: 0.1276 - val_accuracy: 0.9183 - val_loss: 0.2066
# Epoch 20/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 184ms/step - accuracy: 0.9579 - loss: 0.1239 - val_accuracy: 0.9217 - val_loss: 0.2046
# Epoch 21/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 183ms/step - accuracy: 0.9595 - loss: 0.1204 - val_accuracy: 0.9217 - val_loss: 0.2027
# Epoch 22/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 0.9617 - loss: 0.1171 - val_accuracy: 0.9235 - val_loss: 0.2010
# Epoch 23/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9618 - loss: 0.1140 - val_accuracy: 0.9252 - val_loss: 0.1993
# Epoch 24/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 12s 168ms/step - accuracy: 0.9629 - loss: 0.1111 - val_accuracy: 0.9270 - val_loss: 0.1978
# Epoch 25/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 0.9654 - loss: 0.1083 - val_accuracy: 0.9270 - val_loss: 0.1963
# Epoch 26/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.9671 - loss: 0.1056 - val_accuracy: 0.9287 - val_loss: 0.1949
# Epoch 27/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 14s 187ms/step - accuracy: 0.9694 - loss: 0.1031 - val_accuracy: 0.9270 - val_loss: 0.1935
# Epoch 28/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 182ms/step - accuracy: 0.9706 - loss: 0.1007 - val_accuracy: 0.9287 - val_loss: 0.1923
# Epoch 29/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.9706 - loss: 0.0984 - val_accuracy: 0.9287 - val_loss: 0.1911
# Epoch 30/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.9708 - loss: 0.0961 - val_accuracy: 0.9270 - val_loss: 0.1900
# Epoch 31/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 14s 189ms/step - accuracy: 0.9709 - loss: 0.0940 - val_accuracy: 0.9270 - val_loss: 0.1889
# Epoch 32/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - accuracy: 0.9723 - loss: 0.0920 - val_accuracy: 0.9270 - val_loss: 0.1880
# Epoch 33/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 178ms/step - accuracy: 0.9745 - loss: 0.0900 - val_accuracy: 0.9322 - val_loss: 0.1871
# Epoch 34/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 14s 191ms/step - accuracy: 0.9751 - loss: 0.0881 - val_accuracy: 0.9322 - val_loss: 0.1863
# Epoch 35/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 14s 201ms/step - accuracy: 0.9763 - loss: 0.0862 - val_accuracy: 0.9339 - val_loss: 0.1855
# Epoch 36/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 14s 201ms/step - accuracy: 0.9762 - loss: 0.0845 - val_accuracy: 0.9339 - val_loss: 0.1849
# Epoch 37/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 14s 198ms/step - accuracy: 0.9762 - loss: 0.0828 - val_accuracy: 0.9322 - val_loss: 0.1843
# Epoch 38/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 14s 197ms/step - accuracy: 0.9762 - loss: 0.0811 - val_accuracy: 0.9322 - val_loss: 0.1838
# Epoch 39/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 14s 199ms/step - accuracy: 0.9766 - loss: 0.0795 - val_accuracy: 0.9304 - val_loss: 0.1834
# Epoch 40/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 12s 160ms/step - accuracy: 0.9766 - loss: 0.0779 - val_accuracy: 0.9339 - val_loss: 0.1832
# Epoch 41/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 188ms/step - accuracy: 0.9795 - loss: 0.0764 - val_accuracy: 0.9357 - val_loss: 0.1829
# Epoch 42/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 183ms/step - accuracy: 0.9799 - loss: 0.0750 - val_accuracy: 0.9339 - val_loss: 0.1828
# Epoch 43/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9799 - loss: 0.0735 - val_accuracy: 0.9339 - val_loss: 0.1828
# Epoch 44/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 12s 171ms/step - accuracy: 0.9797 - loss: 0.0721 - val_accuracy: 0.9304 - val_loss: 0.1829
# Epoch 45/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 175ms/step - accuracy: 0.9798 - loss: 0.0708 - val_accuracy: 0.9322 - val_loss: 0.1830
# Epoch 46/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 143ms/step - accuracy: 0.9800 - loss: 0.0695 - val_accuracy: 0.9304 - val_loss: 0.1832
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Validation: 	Fold 1 - Loss: 0.1828, Accuracy: 0.9339, Precision: 0.9342, Recall: 0.9320, F1 Score: 0.9330, AUC Score: 0.9736
# Model with best F1 score during Validation saved at Fold 1 with F1 Score of 0.9330
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step
#
# Fold 2/5...
# Training with frozen base layers for 50 epochs...
# Epoch 1/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 14s 162ms/step - accuracy: 0.6966 - loss: 0.5913 - val_accuracy: 0.8296 - val_loss: 0.3760
# Epoch 2/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - accuracy: 0.8189 - loss: 0.3897 - val_accuracy: 0.8678 - val_loss: 0.3119
# Epoch 3/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.8610 - loss: 0.3209 - val_accuracy: 0.8887 - val_loss: 0.2764
# Epoch 4/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.8827 - loss: 0.2793 - val_accuracy: 0.8974 - val_loss: 0.2543
# Epoch 5/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9042 - loss: 0.2503 - val_accuracy: 0.9078 - val_loss: 0.2392
# Epoch 6/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9191 - loss: 0.2285 - val_accuracy: 0.9113 - val_loss: 0.2283
# Epoch 7/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9277 - loss: 0.2114 - val_accuracy: 0.9148 - val_loss: 0.2201
# Epoch 8/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9308 - loss: 0.1974 - val_accuracy: 0.9148 - val_loss: 0.2136
# Epoch 9/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 159ms/step - accuracy: 0.9349 - loss: 0.1856 - val_accuracy: 0.9148 - val_loss: 0.2084
# Epoch 10/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9366 - loss: 0.1756 - val_accuracy: 0.9148 - val_loss: 0.2041
# Epoch 11/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 180ms/step - accuracy: 0.9371 - loss: 0.1668 - val_accuracy: 0.9148 - val_loss: 0.2006
# Epoch 12/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9419 - loss: 0.1590 - val_accuracy: 0.9148 - val_loss: 0.1976
# Epoch 13/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 180ms/step - accuracy: 0.9424 - loss: 0.1520 - val_accuracy: 0.9130 - val_loss: 0.1951
# Epoch 14/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9467 - loss: 0.1457 - val_accuracy: 0.9130 - val_loss: 0.1930
# Epoch 15/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 183ms/step - accuracy: 0.9510 - loss: 0.1400 - val_accuracy: 0.9130 - val_loss: 0.1912
# Epoch 16/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9557 - loss: 0.1347 - val_accuracy: 0.9130 - val_loss: 0.1897
# Epoch 17/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9557 - loss: 0.1299 - val_accuracy: 0.9148 - val_loss: 0.1884
# Epoch 18/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 181ms/step - accuracy: 0.9594 - loss: 0.1254 - val_accuracy: 0.9130 - val_loss: 0.1874
# Epoch 19/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 183ms/step - accuracy: 0.9644 - loss: 0.1212 - val_accuracy: 0.9165 - val_loss: 0.1865
# Epoch 20/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9664 - loss: 0.1173 - val_accuracy: 0.9148 - val_loss: 0.1858
# Epoch 21/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9689 - loss: 0.1137 - val_accuracy: 0.9148 - val_loss: 0.1852
# Epoch 22/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9692 - loss: 0.1103 - val_accuracy: 0.9165 - val_loss: 0.1848
# Epoch 23/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9707 - loss: 0.1070 - val_accuracy: 0.9148 - val_loss: 0.1845
# Epoch 24/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9736 - loss: 0.1040 - val_accuracy: 0.9148 - val_loss: 0.1843
# Epoch 25/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9744 - loss: 0.1011 - val_accuracy: 0.9183 - val_loss: 0.1842
# Epoch 26/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9748 - loss: 0.0984 - val_accuracy: 0.9183 - val_loss: 0.1842
# Epoch 27/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.9755 - loss: 0.0957 - val_accuracy: 0.9165 - val_loss: 0.1843
# Epoch 28/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.9756 - loss: 0.0933 - val_accuracy: 0.9183 - val_loss: 0.1844
# Epoch 29/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.9764 - loss: 0.0909 - val_accuracy: 0.9200 - val_loss: 0.1847
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step
#
# Validation: 	Fold 2 - Loss: 0.1842, Accuracy: 0.9183, Precision: 0.9189, Recall: 0.9157, F1 Score: 0.9170, AUC Score: 0.9702
#
# Fold 3/5...
# Training with frozen base layers for 50 epochs...
# Epoch 1/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.6567 - loss: 0.6522 - val_accuracy: 0.7857 - val_loss: 0.4442
# Epoch 2/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - accuracy: 0.8525 - loss: 0.3769 - val_accuracy: 0.8328 - val_loss: 0.3753
# Epoch 3/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.8861 - loss: 0.3083 - val_accuracy: 0.8484 - val_loss: 0.3400
# Epoch 4/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - accuracy: 0.9023 - loss: 0.2684 - val_accuracy: 0.8693 - val_loss: 0.3172
# Epoch 5/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - accuracy: 0.9180 - loss: 0.2414 - val_accuracy: 0.8780 - val_loss: 0.3005
# Epoch 6/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9255 - loss: 0.2212 - val_accuracy: 0.8780 - val_loss: 0.2875
# Epoch 7/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9314 - loss: 0.2051 - val_accuracy: 0.8798 - val_loss: 0.2771
# Epoch 8/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9388 - loss: 0.1918 - val_accuracy: 0.8815 - val_loss: 0.2685
# Epoch 9/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9429 - loss: 0.1805 - val_accuracy: 0.8885 - val_loss: 0.2615
# Epoch 10/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9444 - loss: 0.1707 - val_accuracy: 0.8920 - val_loss: 0.2557
# Epoch 11/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9450 - loss: 0.1621 - val_accuracy: 0.8920 - val_loss: 0.2508
# Epoch 12/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9508 - loss: 0.1544 - val_accuracy: 0.8972 - val_loss: 0.2468
# Epoch 13/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9512 - loss: 0.1476 - val_accuracy: 0.9007 - val_loss: 0.2435
# Epoch 14/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9546 - loss: 0.1413 - val_accuracy: 0.9007 - val_loss: 0.2408
# Epoch 15/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9574 - loss: 0.1357 - val_accuracy: 0.8990 - val_loss: 0.2385
# Epoch 16/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9601 - loss: 0.1305 - val_accuracy: 0.9007 - val_loss: 0.2366
# Epoch 17/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9614 - loss: 0.1257 - val_accuracy: 0.9024 - val_loss: 0.2350
# Epoch 18/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 154ms/step - accuracy: 0.9636 - loss: 0.1212 - val_accuracy: 0.9024 - val_loss: 0.2337
# Epoch 19/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - accuracy: 0.9638 - loss: 0.1171 - val_accuracy: 0.9024 - val_loss: 0.2326
# Epoch 20/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9660 - loss: 0.1132 - val_accuracy: 0.9024 - val_loss: 0.2316
# Epoch 21/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 155ms/step - accuracy: 0.9671 - loss: 0.1096 - val_accuracy: 0.9024 - val_loss: 0.2308
# Epoch 22/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9682 - loss: 0.1062 - val_accuracy: 0.9024 - val_loss: 0.2301
# Epoch 23/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9694 - loss: 0.1030 - val_accuracy: 0.9042 - val_loss: 0.2295
# Epoch 24/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9696 - loss: 0.0999 - val_accuracy: 0.9059 - val_loss: 0.2290
# Epoch 25/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9706 - loss: 0.0971 - val_accuracy: 0.9077 - val_loss: 0.2285
# Epoch 26/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9721 - loss: 0.0944 - val_accuracy: 0.9077 - val_loss: 0.2280
# Epoch 27/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9731 - loss: 0.0918 - val_accuracy: 0.9059 - val_loss: 0.2275
# Epoch 28/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9731 - loss: 0.0893 - val_accuracy: 0.9077 - val_loss: 0.2271
# Epoch 29/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9746 - loss: 0.0870 - val_accuracy: 0.9077 - val_loss: 0.2267
# Epoch 30/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9746 - loss: 0.0848 - val_accuracy: 0.9094 - val_loss: 0.2263
# Epoch 31/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9758 - loss: 0.0827 - val_accuracy: 0.9094 - val_loss: 0.2259
# Epoch 32/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9768 - loss: 0.0806 - val_accuracy: 0.9111 - val_loss: 0.2256
# Epoch 33/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9771 - loss: 0.0787 - val_accuracy: 0.9077 - val_loss: 0.2252
# Epoch 34/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9792 - loss: 0.0768 - val_accuracy: 0.9042 - val_loss: 0.2248
# Epoch 35/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9806 - loss: 0.0750 - val_accuracy: 0.9077 - val_loss: 0.2245
# Epoch 36/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9825 - loss: 0.0733 - val_accuracy: 0.9094 - val_loss: 0.2242
# Epoch 37/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9835 - loss: 0.0717 - val_accuracy: 0.9129 - val_loss: 0.2239
# Epoch 38/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9836 - loss: 0.0701 - val_accuracy: 0.9129 - val_loss: 0.2237
# Epoch 39/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9847 - loss: 0.0686 - val_accuracy: 0.9129 - val_loss: 0.2235
# Epoch 40/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9848 - loss: 0.0671 - val_accuracy: 0.9094 - val_loss: 0.2233
# Epoch 41/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9848 - loss: 0.0657 - val_accuracy: 0.9094 - val_loss: 0.2232
# Epoch 42/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9848 - loss: 0.0644 - val_accuracy: 0.9094 - val_loss: 0.2232
# Epoch 43/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.9854 - loss: 0.0631 - val_accuracy: 0.9111 - val_loss: 0.2232
# Epoch 44/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.9869 - loss: 0.0618 - val_accuracy: 0.9094 - val_loss: 0.2233
# Epoch 45/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.9890 - loss: 0.0606 - val_accuracy: 0.9059 - val_loss: 0.2235
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
#
# Validation: 	Fold 3 - Loss: 0.2232, Accuracy: 0.9094, Precision: 0.9128, Recall: 0.9047, F1 Score: 0.9076, AUC Score: 0.9628
#
# Fold 4/5...
# Training with frozen base layers for 50 epochs...
# Epoch 1/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - accuracy: 0.6003 - loss: 0.7035 - val_accuracy: 0.7700 - val_loss: 0.4811
# Epoch 2/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 152ms/step - accuracy: 0.8285 - loss: 0.3915 - val_accuracy: 0.8188 - val_loss: 0.3910
# Epoch 3/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 152ms/step - accuracy: 0.8713 - loss: 0.3254 - val_accuracy: 0.8415 - val_loss: 0.3462
# Epoch 4/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - accuracy: 0.8903 - loss: 0.2866 - val_accuracy: 0.8589 - val_loss: 0.3185
# Epoch 5/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 152ms/step - accuracy: 0.9043 - loss: 0.2596 - val_accuracy: 0.8728 - val_loss: 0.2992
# Epoch 6/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 152ms/step - accuracy: 0.9124 - loss: 0.2392 - val_accuracy: 0.8798 - val_loss: 0.2846
# Epoch 7/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 152ms/step - accuracy: 0.9204 - loss: 0.2228 - val_accuracy: 0.8868 - val_loss: 0.2730
# Epoch 8/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 152ms/step - accuracy: 0.9283 - loss: 0.2094 - val_accuracy: 0.8955 - val_loss: 0.2634
# Epoch 9/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - accuracy: 0.9308 - loss: 0.1980 - val_accuracy: 0.8937 - val_loss: 0.2552
# Epoch 10/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - accuracy: 0.9350 - loss: 0.1882 - val_accuracy: 0.8937 - val_loss: 0.2483
# Epoch 11/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9373 - loss: 0.1796 - val_accuracy: 0.8937 - val_loss: 0.2422
# Epoch 12/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9433 - loss: 0.1721 - val_accuracy: 0.8937 - val_loss: 0.2368
# Epoch 13/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9441 - loss: 0.1653 - val_accuracy: 0.8937 - val_loss: 0.2320
# Epoch 14/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9441 - loss: 0.1592 - val_accuracy: 0.8955 - val_loss: 0.2277
# Epoch 15/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9469 - loss: 0.1536 - val_accuracy: 0.8955 - val_loss: 0.2239
# Epoch 16/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9491 - loss: 0.1485 - val_accuracy: 0.8955 - val_loss: 0.2204
# Epoch 17/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9510 - loss: 0.1438 - val_accuracy: 0.8990 - val_loss: 0.2171
# Epoch 18/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9530 - loss: 0.1394 - val_accuracy: 0.8990 - val_loss: 0.2142
# Epoch 19/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9535 - loss: 0.1354 - val_accuracy: 0.9024 - val_loss: 0.2114
# Epoch 20/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9546 - loss: 0.1316 - val_accuracy: 0.9024 - val_loss: 0.2089
# Epoch 21/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9557 - loss: 0.1280 - val_accuracy: 0.9024 - val_loss: 0.2065
# Epoch 22/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9570 - loss: 0.1247 - val_accuracy: 0.9077 - val_loss: 0.2042
# Epoch 23/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9582 - loss: 0.1215 - val_accuracy: 0.9077 - val_loss: 0.2021
# Epoch 24/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9589 - loss: 0.1185 - val_accuracy: 0.9077 - val_loss: 0.2002
# Epoch 25/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9599 - loss: 0.1157 - val_accuracy: 0.9059 - val_loss: 0.1983
# Epoch 26/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9611 - loss: 0.1130 - val_accuracy: 0.9059 - val_loss: 0.1965
# Epoch 27/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9624 - loss: 0.1104 - val_accuracy: 0.9077 - val_loss: 0.1948
# Epoch 28/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9633 - loss: 0.1080 - val_accuracy: 0.9094 - val_loss: 0.1932
# Epoch 29/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9640 - loss: 0.1056 - val_accuracy: 0.9111 - val_loss: 0.1916
# Epoch 30/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9641 - loss: 0.1034 - val_accuracy: 0.9146 - val_loss: 0.1902
# Epoch 31/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9621 - loss: 0.1012 - val_accuracy: 0.9146 - val_loss: 0.1888
# Epoch 32/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9630 - loss: 0.0991 - val_accuracy: 0.9146 - val_loss: 0.1875
# Epoch 33/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9645 - loss: 0.0971 - val_accuracy: 0.9146 - val_loss: 0.1862
# Epoch 34/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9647 - loss: 0.0951 - val_accuracy: 0.9181 - val_loss: 0.1851
# Epoch 35/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9655 - loss: 0.0933 - val_accuracy: 0.9164 - val_loss: 0.1840
# Epoch 36/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9663 - loss: 0.0915 - val_accuracy: 0.9181 - val_loss: 0.1830
# Epoch 37/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9666 - loss: 0.0897 - val_accuracy: 0.9199 - val_loss: 0.1821
# Epoch 38/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9691 - loss: 0.0880 - val_accuracy: 0.9181 - val_loss: 0.1813
# Epoch 39/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 13s 180ms/step - accuracy: 0.9692 - loss: 0.0864 - val_accuracy: 0.9199 - val_loss: 0.1806
# Epoch 40/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9686 - loss: 0.0848 - val_accuracy: 0.9199 - val_loss: 0.1800
# Epoch 41/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9686 - loss: 0.0832 - val_accuracy: 0.9199 - val_loss: 0.1795
# Epoch 42/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.9725 - loss: 0.0817 - val_accuracy: 0.9199 - val_loss: 0.1791
# Epoch 43/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.9730 - loss: 0.0802 - val_accuracy: 0.9199 - val_loss: 0.1787
# Epoch 44/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9728 - loss: 0.0787 - val_accuracy: 0.9164 - val_loss: 0.1785
# Epoch 45/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9730 - loss: 0.0773 - val_accuracy: 0.9181 - val_loss: 0.1784
# Epoch 46/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9730 - loss: 0.0759 - val_accuracy: 0.9199 - val_loss: 0.1784
# Epoch 47/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.9730 - loss: 0.0746 - val_accuracy: 0.9199 - val_loss: 0.1785
# Epoch 48/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.9742 - loss: 0.0732 - val_accuracy: 0.9199 - val_loss: 0.1786
# Epoch 49/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.9742 - loss: 0.0719 - val_accuracy: 0.9216 - val_loss: 0.1789
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
#
# Validation: 	Fold 4 - Loss: 0.1784, Accuracy: 0.9199, Precision: 0.9203, Recall: 0.9175, F1 Score: 0.9187, AUC Score: 0.9749
#
# Fold 5/5...
# Training with frozen base layers for 50 epochs...
# Epoch 1/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 14s 166ms/step - accuracy: 0.6590 - loss: 0.6563 - val_accuracy: 0.8066 - val_loss: 0.4510
# Epoch 2/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.8454 - loss: 0.3677 - val_accuracy: 0.8362 - val_loss: 0.3784
# Epoch 3/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 158ms/step - accuracy: 0.8764 - loss: 0.3036 - val_accuracy: 0.8484 - val_loss: 0.3341
# Epoch 4/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.8923 - loss: 0.2652 - val_accuracy: 0.8659 - val_loss: 0.3043
# Epoch 5/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9081 - loss: 0.2384 - val_accuracy: 0.8711 - val_loss: 0.2839
# Epoch 6/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 158ms/step - accuracy: 0.9233 - loss: 0.2183 - val_accuracy: 0.8815 - val_loss: 0.2693
# Epoch 7/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9264 - loss: 0.2024 - val_accuracy: 0.8902 - val_loss: 0.2584
# Epoch 8/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9341 - loss: 0.1894 - val_accuracy: 0.9007 - val_loss: 0.2501
# Epoch 9/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9387 - loss: 0.1785 - val_accuracy: 0.9024 - val_loss: 0.2437
# Epoch 10/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 158ms/step - accuracy: 0.9438 - loss: 0.1691 - val_accuracy: 0.9024 - val_loss: 0.2386
# Epoch 11/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9466 - loss: 0.1609 - val_accuracy: 0.9024 - val_loss: 0.2346
# Epoch 12/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9484 - loss: 0.1537 - val_accuracy: 0.9024 - val_loss: 0.2313
# Epoch 13/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 158ms/step - accuracy: 0.9502 - loss: 0.1472 - val_accuracy: 0.9024 - val_loss: 0.2286
# Epoch 14/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9532 - loss: 0.1413 - val_accuracy: 0.9042 - val_loss: 0.2264
# Epoch 15/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9557 - loss: 0.1360 - val_accuracy: 0.9059 - val_loss: 0.2246
# Epoch 16/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9568 - loss: 0.1311 - val_accuracy: 0.9059 - val_loss: 0.2231
# Epoch 17/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9580 - loss: 0.1266 - val_accuracy: 0.9059 - val_loss: 0.2218
# Epoch 18/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9593 - loss: 0.1225 - val_accuracy: 0.9059 - val_loss: 0.2207
# Epoch 19/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9634 - loss: 0.1187 - val_accuracy: 0.9094 - val_loss: 0.2198
# Epoch 20/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9652 - loss: 0.1151 - val_accuracy: 0.9094 - val_loss: 0.2189
# Epoch 21/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 158ms/step - accuracy: 0.9659 - loss: 0.1118 - val_accuracy: 0.9094 - val_loss: 0.2182
# Epoch 22/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 12s 161ms/step - accuracy: 0.9659 - loss: 0.1086 - val_accuracy: 0.9111 - val_loss: 0.2175
# Epoch 23/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 160ms/step - accuracy: 0.9669 - loss: 0.1057 - val_accuracy: 0.9111 - val_loss: 0.2169
# Epoch 24/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9690 - loss: 0.1030 - val_accuracy: 0.9129 - val_loss: 0.2163
# Epoch 25/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9704 - loss: 0.1004 - val_accuracy: 0.9129 - val_loss: 0.2157
# Epoch 26/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9709 - loss: 0.0979 - val_accuracy: 0.9129 - val_loss: 0.2151
# Epoch 27/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9709 - loss: 0.0956 - val_accuracy: 0.9129 - val_loss: 0.2145
# Epoch 28/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9714 - loss: 0.0934 - val_accuracy: 0.9146 - val_loss: 0.2140
# Epoch 29/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9725 - loss: 0.0912 - val_accuracy: 0.9164 - val_loss: 0.2134
# Epoch 30/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9739 - loss: 0.0892 - val_accuracy: 0.9181 - val_loss: 0.2127
# Epoch 31/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9755 - loss: 0.0873 - val_accuracy: 0.9181 - val_loss: 0.2121
# Epoch 32/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9760 - loss: 0.0855 - val_accuracy: 0.9233 - val_loss: 0.2114
# Epoch 33/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9760 - loss: 0.0837 - val_accuracy: 0.9251 - val_loss: 0.2107
# Epoch 34/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 158ms/step - accuracy: 0.9785 - loss: 0.0820 - val_accuracy: 0.9251 - val_loss: 0.2100
# Epoch 35/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 158ms/step - accuracy: 0.9786 - loss: 0.0804 - val_accuracy: 0.9233 - val_loss: 0.2092
# Epoch 36/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9813 - loss: 0.0788 - val_accuracy: 0.9233 - val_loss: 0.2084
# Epoch 37/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 156ms/step - accuracy: 0.9811 - loss: 0.0773 - val_accuracy: 0.9216 - val_loss: 0.2076
# Epoch 38/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 156ms/step - accuracy: 0.9811 - loss: 0.0758 - val_accuracy: 0.9216 - val_loss: 0.2068
# Epoch 39/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9811 - loss: 0.0744 - val_accuracy: 0.9233 - val_loss: 0.2060
# Epoch 40/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9811 - loss: 0.0730 - val_accuracy: 0.9233 - val_loss: 0.2052
# Epoch 41/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 156ms/step - accuracy: 0.9812 - loss: 0.0717 - val_accuracy: 0.9251 - val_loss: 0.2044
# Epoch 42/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9811 - loss: 0.0704 - val_accuracy: 0.9233 - val_loss: 0.2036
# Epoch 43/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9818 - loss: 0.0691 - val_accuracy: 0.9251 - val_loss: 0.2029
# Epoch 44/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9818 - loss: 0.0679 - val_accuracy: 0.9251 - val_loss: 0.2023
# Epoch 45/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 158ms/step - accuracy: 0.9799 - loss: 0.0667 - val_accuracy: 0.9303 - val_loss: 0.2017
# Epoch 46/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9815 - loss: 0.0655 - val_accuracy: 0.9286 - val_loss: 0.2012
# Epoch 47/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9818 - loss: 0.0644 - val_accuracy: 0.9268 - val_loss: 0.2008
# Epoch 48/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9818 - loss: 0.0632 - val_accuracy: 0.9268 - val_loss: 0.2006
# Epoch 49/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9825 - loss: 0.0621 - val_accuracy: 0.9286 - val_loss: 0.2004
# Epoch 50/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.9834 - loss: 0.0610 - val_accuracy: 0.9286 - val_loss: 0.2004
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step
#
# Validation: 	Fold 5 - Loss: 0.2004, Accuracy: 0.9286, Precision: 0.9299, Recall: 0.9258, F1 Score: 0.9275, AUC Score: 0.9716

# %% [markdown]
# ## Testing

# %%
model = tf.keras.models.load_model('../saved_models/mobilenetv2_best_f1score_fold_1.h5')

# once training is complete, evaluate on the held-out test set
print("Evaluating the best model on the held-out test set...")
test_ds = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
test_ds = test_ds.map(lambda x, y: (normalization_layer(x), y)).batch(batch_size)

test_predictions = model.predict(test_ds)
avg_test_loss = model.evaluate(test_ds, verbose=0)[0]
avg_test_accuracy, avg_test_precision, avg_test_recall, avg_test_f1, avg_test_auc = calculate_metrics(
    np.concatenate([y for x, y in test_ds]), test_predictions
)

print(f"\nTest Set Evaluation - Loss: {avg_test_loss:.4f}, Accuracy: {avg_test_accuracy:.4f}, Precision: {avg_test_precision:.4f}, Recall: {avg_test_recall:.4f}, F1 Score: {avg_test_f1:.4f}, AUC Score: {avg_test_auc:.4f}")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Evaluating the best model on the held-out test set...
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
#
# Test Set Evaluation - Loss: 0.2367, Accuracy: 0.9219, Precision: 0.9218, Recall: 0.9200, F1 Score: 0.9208, AUC Score: 0.9586
